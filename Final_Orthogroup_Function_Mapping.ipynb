# %% [markdown]
# ### Getting the Functions for All OrthoGroups from Closely related species (Using OrthoFinder output)

# %%
## Reading and renaming the columns 
import pandas as pd 
OrthoGroup = pd.read_excel("Orthogroups-fixFormat-2.xlsx")
OrthoGroupDF = OrthoGroup.rename(columns={"Unnamed: 0":"Orthogroup"})
OrthoGroupDF
# Out:
#       Orthogroup                                      Aedes_aegypti  \
# 0      OG0000000                                                NaN
# 1      OG0000001                       AAEL026431-PA, AAEL026853-PA
# 2      OG0000002  AAEL000501-PB, AAEL000517-PB, AAEL003673-PB, A...
# 3      OG0000003  AAEL003669-PA, AAEL003687-PB, AAEL003706-PB, A...
# 4      OG0000004  AAEL000492-PB, AAEL003685-PB, AAEL006158-PA, A...
# ...          ...                                                ...
# 11105  OG0011105                                                NaN
# 11106  OG0011106                                                NaN
# 11107  OG0011107                                                NaN
# 11108  OG0011108                                                NaN
# 11109  OG0011109                                                NaN
#
#                                        Anopheles_gambiae  \
# 0                                                    NaN
# 1                                                    NaN
# 2      AGAP003909-PA, AGAP005023-PA, AGAP005026-PA, A...
# 3      AGAP003911-PA, AGAP003913-PA, AGAP011845-PA, A...
# 4      AGAP001813-PA, AGAP001813-PB, AGAP003910-PA, A...
# ...                                                  ...
# 11105                                                NaN
# 11106                                                NaN
# 11107                                                NaN
# 11108                                                NaN
# 11109                                                NaN
#
#                                   Culex_quinquefasciatus  \
# 0                                          CPIJ003781-PA
# 1      CPIJ003141-PA, CPIJ006112-PA, CPIJ011828-PA, C...
# 2      CPIJ005873-PA, CPIJ010359-PA, CPIJ012378-PA, C...
# 3      CPIJ001452-PA, CPIJ004104-PA, CPIJ005867-PA, C...
# 4      CPIJ005872-PA, CPIJ006050-PA, CPIJ008605-PA, C...
# ...                                                  ...
# 11105                                                NaN
# 11106                                                NaN
# 11107                                                NaN
# 11108                                                NaN
# 11109                                                NaN
#
#                                  Drosophila_melanogaster  \
# 0                                                    NaN
# 1                                                    NaN
# 2      FBpp0082421, FBpp0082422, FBpp0082423, FBpp008...
# 3      FBpp0085249, FBpp0091055, FBpp0091060, FBpp009...
# 4      FBpp0071280, FBpp0071281, FBpp0071282, FBpp007...
# ...                                                  ...
# 11105                                                NaN
# 11106                                                NaN
# 11107                                                NaN
# 11108                                                NaN
# 11109                                                NaN
#
#                                         Wyeomyia_smithii
# 0      maker-tig00000051|arrow-exonerate_est2genome-g...
# 1      maker-tig00000078|arrow-exonerate_est2genome-g...
# 2                                                    NaN
# 3      maker-tig00265988|arrow-exonerate_est2genome-g...
# 4      maker-tig00078760|arrow-exonerate_est2genome-g...
# ...                                                  ...
# 11105  maker-tig00001261|arrow-exonerate_est2genome-g...
# 11106  maker-tig00055620|arrow-exonerate_est2genome-g...
# 11107  maker-tig00031758|arrow-exonerate_est2genome-g...
# 11108  maker-tig00267066|arrow-exonerate_est2genome-g...
# 11109  maker-tig00031038|arrow-exonerate_est2genome-g...
#
# [11110 rows x 6 columns]

# %%
OrthoGroupList = list(OrthoGroupDF["Orthogroup"])

# %%
UniportOutput = pd.read_excel("Final_output.xlsx")
UniportOutput
# Out:
#       Unnamed: 0 Orthogroup  \
# 0              0  OG0000002
# 1              1  OG0000003
# 2              2  OG0000004
# 3              3  OG0000006
# 4              4  OG0000174
# ...          ...        ...
# 2896        2896  OG0008738
# 2897        2897  OG0009861
# 2898        2898  OG0010523
# 2899        2899  OG0010980
# 2900        2900  OG0011008
#
#                                              Flybase ID  \
# 0     ['FBpp0306146', 'FBpp0082421', 'FBpp0082422', ...
# 1                                       ['FBpp0091111']
# 2     ['FBpp0071280', 'FBpp0309302', 'FBpp0091112', ...
# 3                                       ['FBpp0288822']
# 4                        ['FBpp0288827', 'FBpp0288821']
# ...                                                 ...
# 2896                                    ['FBpp0305468']
# 2897                                    ['FBpp0082243']
# 2898                                    ['FBpp0080674']
# 2899                                    ['FBpp0289473']
# 2900                                    ['FBpp0302664']
#
#                                         Gene ID  \
# 0      ['CG3379', 'CG3379', 'CG3379', 'CG3379']
# 1                                   ['CG33865']
# 2     ['CG8989', 'CG8989', 'CG33866', 'CG5825']
# 3                                   ['CG42256']
# 4                        ['CG42256', 'CG42256']
# ...                                         ...
# 2896                                 ['CG9097']
# 2897                                 ['CG8458']
# 2898                                ['CG10385']
# 2899                                ['CG42456']
# 2900                                 ['CG1257']
#
#                                           Protein names  \
# 0     ['Histone H4', 'Histone H4', 'Histone H4', 'Hi...
# 1                                       ['Histone H2A']
# 2     ['Histone H3.3B (H3.B)', 'Histone H3.3B (H3.B)...
# 3     ['Down syndrome cell adhesion molecule-like pr...
# 4     ['Down syndrome cell adhesion molecule-like pr...
# ...                                                 ...
# 2896                          ['Protein bric-a-brac 1']
# 2897  ['Wnt inhibitor of Dorsal protein (Protein Wnt...
# 2898                 ['Protein male-specific lethal-1']
# 2899  ['Dolichol phosphate-mannose biosynthesis regu...
# 2900  ['Aromatic amino acid transport protein AroP (...
#
#                                           Function [CC]
# 0     ['FUNCTION: Core component of nucleosome. Nucl...
# 1     ['FUNCTION: Core component of nucleosome. Nucl...
# 2     ['FUNCTION: Variant histone H3 which replaces ...
# 3     ['FUNCTION: Cell adhesion molecule. {ECO:00002...
# 4     ['FUNCTION: Cell adhesion molecule. {ECO:00002...
# ...                                                 ...
# 2896  ['FUNCTION: Probably acts as a transcriptional...
# 2897  ['FUNCTION: Binds as a ligand to a family of f...
# 2898  ['FUNCTION: The Msl proteins are essential for...
# 2899  ['FUNCTION: Regulatory subunit of the dolichol...
# 2900  ['FUNCTION: Permease that is involved in the t...
#
# [2901 rows x 6 columns]

# %% [markdown]
# ## Using OrthoGroupDF and UniportOutput DataFrame to get Missing UniportIDs that does not have any function in UniportOutput.

# %%
def getMissingOrthogroup(primary, secondary):
    OrthoGroup_GeneName = primary
    UniportOutput = secondary
    UniportOutput_MissingFrom_OrthoGroup_GeneName = []

    OrthoGroup_GeneName_Orthogroup = list(OrthoGroup_GeneName['Orthogroup'])
    UniportOutput_Orthogroup = list(UniportOutput['Orthogroup'])

    for i in range(len(OrthoGroup_GeneName_Orthogroup)): # Len of bigger df to avoid index out of bound expection
        if OrthoGroup_GeneName_Orthogroup[i] not in UniportOutput_Orthogroup:
            UniportOutput_MissingFrom_OrthoGroup_GeneName.append(OrthoGroup_GeneName_Orthogroup[i])

    UniportOutput_MsnFrm_OrthoGroup_GeneName = pd.DataFrame(UniportOutput_MissingFrom_OrthoGroup_GeneName, columns = ['Orthogroup'])
    return UniportOutput_MsnFrm_OrthoGroup_GeneName

# %%
OrthoGroup_Missing_Uniport = getMissingOrthogroup(OrthoGroupDF, UniportOutput)
OrthoGroup_Missing_Uniport
# Out:
#      Orthogroup
# 0     OG0000000
# 1     OG0000001
# 2     OG0000005
# 3     OG0000007
# 4     OG0000008
# ...         ...
# 8204  OG0011105
# 8205  OG0011106
# 8206  OG0011107
# 8207  OG0011108
# 8208  OG0011109
#
# [8209 rows x 1 columns]

# %%
# Now we are taking out the records of Missing_uniport1 from the main Orhthogroup table
Missing_uniport3 = pd.merge(OrthoGroup_Missing_Uniport, OrthoGroupDF, how="inner", on="Orthogroup")
Missing_uniport3
# Out:
#      Orthogroup                                      Aedes_aegypti  \
# 0     OG0000000                                                NaN
# 1     OG0000001                       AAEL026431-PA, AAEL026853-PA
# 2     OG0000005  AAEL001713-PA, AAEL003156-PA, AAEL003156-PB, A...
# 3     OG0000007  AAEL020023-PA, AAEL020030-PA, AAEL020063-PA, A...
# 4     OG0000008  AAEL006665-PA, AAEL011906-PA, AAEL018018-PA, A...
# ...         ...                                                ...
# 8204  OG0011105                                                NaN
# 8205  OG0011106                                                NaN
# 8206  OG0011107                                                NaN
# 8207  OG0011108                                                NaN
# 8208  OG0011109                                                NaN
#
#                                       Anopheles_gambiae  \
# 0                                                   NaN
# 1                                                   NaN
# 2     AGAP004916-PA, AGAP004917-PA, AGAP004918-PA, A...
# 3     AGAP012199-PA, AGAP012201-PA, AGAP012202-PA, A...
# 4     AGAP005264-PA, AGAP005265-PA, AGAP005266-PA, A...
# ...                                                 ...
# 8204                                                NaN
# 8205                                                NaN
# 8206                                                NaN
# 8207                                                NaN
# 8208                                                NaN
#
#                                  Culex_quinquefasciatus  \
# 0                                         CPIJ003781-PA
# 1     CPIJ003141-PA, CPIJ006112-PA, CPIJ011828-PA, C...
# 2     CPIJ000314-PA, CPIJ000331-PA, CPIJ000332-PA, C...
# 3     CPIJ010361-PA, CPIJ012376-PA, CPIJ012381-PA, C...
# 4     CPIJ010358-PA, CPIJ012377-PA, CPIJ012385-PA, C...
# ...                                                 ...
# 8204                                                NaN
# 8205                                                NaN
# 8206                                                NaN
# 8207                                                NaN
# 8208                                                NaN
#
#                                 Drosophila_melanogaster  \
# 0                                                   NaN
# 1                                                   NaN
# 2     FBpp0071343, FBpp0071364, FBpp0071674, FBpp008...
# 3     FBpp0085281, FBpp0091113, FBpp0091115, FBpp009...
# 4     FBpp0085248, FBpp0091050, FBpp0091052, FBpp009...
# ...                                                 ...
# 8204                                                NaN
# 8205                                                NaN
# 8206                                                NaN
# 8207                                                NaN
# 8208                                                NaN
#
#                                        Wyeomyia_smithii
# 0     maker-tig00000051|arrow-exonerate_est2genome-g...
# 1     maker-tig00000078|arrow-exonerate_est2genome-g...
# 2     maker-tig00006038|arrow-exonerate_est2genome-g...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8204  maker-tig00001261|arrow-exonerate_est2genome-g...
# 8205  maker-tig00055620|arrow-exonerate_est2genome-g...
# 8206  maker-tig00031758|arrow-exonerate_est2genome-g...
# 8207  maker-tig00267066|arrow-exonerate_est2genome-g...
# 8208  maker-tig00031038|arrow-exonerate_est2genome-g...
#
# [8209 rows x 6 columns]

# %% [markdown]
# ## Using each of the output file from OrthoFinder (Five Species) and getting the GeneNames from OrthoGroupDF and from that we are getting the related functions from each species output files(ex. Aedes_aegypti.xlsx, that have gene name and functions)

# %%
Aedes_aegypti = pd.read_excel("Aedes_aegypti.xlsx")
Aedes_aegypti = Aedes_aegypti.drop("Unnamed: 0", 1)
Aedes_aegypti
Aedes_aegypti_dict = {}
for i in range(len(Aedes_aegypti)):
    Aedes_aegypti_dict[Aedes_aegypti[0][i]] = Aedes_aegypti[1][i]

Aedes_aegypti
# Out:
#                    0                                                  1
# 0      AAEL026602-PA  ['Multicopper oxidase', '-', 'MULTI-COPPER OXI...
# 1      AAEL026330-PA  ['cnmp_10', 'cAMP/cGMP binding motif profile.'...
# 2      AAEL027138-PA  ['NAD binding domain of 6-phosphogluconate deh...
# 3      AAEL007244-PB  ['beta-beta-alpha zinc fingers', 'c2h2final6',...
# 4      AAEL007244-PA  ['beta-beta-alpha zinc fingers', 'c2h2final6',...
# ...              ...                                                ...
# 27601  AAEL013825-PB  ['ATP-DEPENDENT RNA AND DNA HELICASE', 'P-loop...
# 27602  AAEL001503-PC  ['consensus disorder prediction', 'Na+/H+ exch...
# 27603  AAEL010538-PA  ['consensus disorder prediction', 'TRANSLOCATI...
# 27604  AAEL019657-PE  ['IG_3c', 'Ig', '-', 'Ig-like domain profile.'...
# 27605  AAEL027985-PA  ['Glucose/ribitol dehydrogenase family signatu...
#
# [27606 rows x 2 columns]

# %%
def createOrthoFunctionDict(masterDFname, newDict, masterDFColName):
    resultDict = {}
    for i in range(len(masterDFname[masterDFColName])):
        if not isinstance(masterDFname[masterDFColName][i],float):
            for element in masterDFname[masterDFColName][i].split(','):
                if element in newDict:
                    resultDict[masterDFname["Orthogroup"][i]] = [newDict[element.strip()]]
                    resultDict[masterDFname["Orthogroup"][i]].append(newDict[element.strip()])
    
    func = resultDict.values()
    NewDF = pd.DataFrame({"Orthogroup": resultDict.keys(),"Function [CC]":func})

    OrthoGroup_GeneName_IntMissing = getMissingOrthogroup(masterDFname, NewDF)
    OrthoGroup_GeneName_Int = pd.merge(masterDFname, NewDF, on= 'Orthogroup')
    
    return (OrthoGroup_GeneName_IntMissing, OrthoGroup_GeneName_Int)

# %%
## To get all the common orthogroups with functions 
OrthoGroup_GeneName_IntMiss, OrthoGroup_GeneName_Int = createOrthoFunctionDict(Missing_uniport3, Aedes_aegypti_dict, "Aedes_aegypti") 
OrthoGroup_GeneName_Int = OrthoGroup_GeneName_Int.rename(columns={"Function [CC]":"Function"})
OrthoGroup_GeneName_Int
# Out:
#      Orthogroup                                      Aedes_aegypti  \
# 0     OG0000001                       AAEL026431-PA, AAEL026853-PA
# 1     OG0000005  AAEL001713-PA, AAEL003156-PA, AAEL003156-PB, A...
# 2     OG0000007  AAEL020023-PA, AAEL020030-PA, AAEL020063-PA, A...
# 3     OG0000008  AAEL006665-PA, AAEL011906-PA, AAEL018018-PA, A...
# 4     OG0000009  AAEL000665-PA, AAEL007085-PA, AAEL008966-PA, A...
# ...         ...                                                ...
# 7274  OG0010860                                      AAEL020026-PA
# 7275  OG0010862                                      AAEL024444-PA
# 7276  OG0010863                                      AAEL027627-PA
# 7277  OG0010864                                      AAEL028069-PA
# 7278  OG0010865                                      AAEL026810-PA
#
#                                       Anopheles_gambiae  \
# 0                                                   NaN
# 1     AGAP004916-PA, AGAP004917-PA, AGAP004918-PA, A...
# 2     AGAP012199-PA, AGAP012201-PA, AGAP012202-PA, A...
# 3     AGAP005264-PA, AGAP005265-PA, AGAP005266-PA, A...
# 4     AGAP005966-PA, AGAP005967-PA, AGAP005968-PA, A...
# ...                                                 ...
# 7274                                                NaN
# 7275                                                NaN
# 7276                                                NaN
# 7277                                                NaN
# 7278                                                NaN
#
#                                  Culex_quinquefasciatus  \
# 0     CPIJ003141-PA, CPIJ006112-PA, CPIJ011828-PA, C...
# 1     CPIJ000314-PA, CPIJ000331-PA, CPIJ000332-PA, C...
# 2     CPIJ010361-PA, CPIJ012376-PA, CPIJ012381-PA, C...
# 3     CPIJ010358-PA, CPIJ012377-PA, CPIJ012385-PA, C...
# 4     CPIJ000479-PA, CPIJ003020-PA, CPIJ003022-PA, C...
# ...                                                 ...
# 7274                                      CPIJ009466-PA
# 7275                                      CPIJ012105-PA
# 7276                                      CPIJ010880-PA
# 7277                                                NaN
# 7278                                      CPIJ008215-PA
#
#                                 Drosophila_melanogaster  \
# 0                                                   NaN
# 1     FBpp0071343, FBpp0071364, FBpp0071674, FBpp008...
# 2     FBpp0085281, FBpp0091113, FBpp0091115, FBpp009...
# 3     FBpp0085248, FBpp0091050, FBpp0091052, FBpp009...
# 4                              FBpp0074702, FBpp0074745
# ...                                                 ...
# 7274                                                NaN
# 7275                                                NaN
# 7276                                                NaN
# 7277                                                NaN
# 7278                                                NaN
#
#                                        Wyeomyia_smithii  \
# 0     maker-tig00000078|arrow-exonerate_est2genome-g...
# 1     maker-tig00006038|arrow-exonerate_est2genome-g...
# 2                                                   NaN
# 3                                                   NaN
# 4     maker-tig00001741|arrow-exonerate_est2genome-g...
# ...                                                 ...
# 7274                                                NaN
# 7275                                                NaN
# 7276                                                NaN
# 7277  maker-tig00047251|arrow-exonerate_est2genome-g...
# 7278                                                NaN
#
#                                                Function
# 0     [['DNA/RNA polymerases', '-', 'Reverse transcr...
# 1     [['FReD', 'Fibrinogen C-terminal domain-like',...
# 2     [['Histone', 'h2b3', 'Core histone H2A/H2B/H3/...
# 3     [['H15', 'HISTONE H1', '""winged helix"" repre...
# 4     [['Insect cuticle protein', 'Insect cuticle pr...
# ...                                                 ...
# 7274  [['Prokaryotic membrane lipoprotein lipid atta...
# 7275  [['NETRIN RECEPTOR UNC5', 'NETRIN RECEPTOR UNC...
# 7276  [['consensus disorder prediction'], ['consensu...
# 7277                               [['Coil'], ['Coil']]
# 7278  [['Nuclear receptor ligand-binding domain', 'R...
#
# [7279 rows x 7 columns]

# %%
## to get the remaining OrthoGroup IDs without any functions from Aedes_aegypti output
## using that output for next species so we will avoid repeatation
OrthoGroup_GeneName_PresentAA = getMissingOrthogroup(Missing_uniport3, OrthoGroup_GeneName_Int)
OrthoGroup_GeneName_AA = pd.merge(Missing_uniport3, OrthoGroup_GeneName_PresentAA, on= 'Orthogroup')
OrthoGroup_GeneName_AA
# Out:
#     Orthogroup Aedes_aegypti Anopheles_gambiae  \
# 0    OG0000000           NaN               NaN
# 1    OG0000010           NaN               NaN
# 2    OG0000029           NaN               NaN
# 3    OG0000042           NaN               NaN
# 4    OG0000046           NaN               NaN
# ..         ...           ...               ...
# 925  OG0011105           NaN               NaN
# 926  OG0011106           NaN               NaN
# 927  OG0011107           NaN               NaN
# 928  OG0011108           NaN               NaN
# 929  OG0011109           NaN               NaN
#
#                           Culex_quinquefasciatus  \
# 0                                  CPIJ003781-PA
# 1    CPIJ014066-PA, CPIJ017401-PA, CPIJ017423-PA
# 2                                  CPIJ003782-PA
# 3                                  CPIJ007606-PA
# 4                                            NaN
# ..                                           ...
# 925                                          NaN
# 926                                          NaN
# 927                                          NaN
# 928                                          NaN
# 929                                          NaN
#
#                                Drosophila_melanogaster  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    FBpp0072260, FBpp0072261, FBpp0072283, FBpp008...
# ..                                                 ...
# 925                                                NaN
# 926                                                NaN
# 927                                                NaN
# 928                                                NaN
# 929                                                NaN
#
#                                       Wyeomyia_smithii
# 0    maker-tig00000051|arrow-exonerate_est2genome-g...
# 1    maker-tig00001022|arrow-exonerate_est2genome-g...
# 2    maker-tig00000321|arrow-exonerate_est2genome-g...
# 3    maker-tig00000213|arrow-exonerate_est2genome-g...
# 4                                                  NaN
# ..                                                 ...
# 925  maker-tig00001261|arrow-exonerate_est2genome-g...
# 926  maker-tig00055620|arrow-exonerate_est2genome-g...
# 927  maker-tig00031758|arrow-exonerate_est2genome-g...
# 928  maker-tig00267066|arrow-exonerate_est2genome-g...
# 929  maker-tig00031038|arrow-exonerate_est2genome-g...
#
# [930 rows x 6 columns]

# %%
Anopheles_gambiae = pd.read_excel("Anopheles_gambiae.xlsx")
Anopheles_gambiae = Anopheles_gambiae.drop("Unnamed: 0", 1)
Anopheles_gambiae
Anopheles_gambiae_dict = {}
for i in range(len(Anopheles_gambiae)):
    Anopheles_gambiae_dict[Anopheles_gambiae[0][i]] = Anopheles_gambiae[1][i]

# %%
OrthoGroup_GeneName_IntAGMiss, OrthoGroup_GeneName_IntAG = createOrthoFunctionDict(OrthoGroup_GeneName_AA, Anopheles_gambiae_dict, "Anopheles_gambiae") 
OrthoGroup_GeneName_IntAG = OrthoGroup_GeneName_IntAG.rename(columns={"Function [CC]":"Function"})
OrthoGroup_GeneName_IntAG
# Out:
#     Orthogroup Aedes_aegypti  \
# 0    OG0000064           NaN
# 1    OG0000101           NaN
# 2    OG0000152           NaN
# 3    OG0000168           NaN
# 4    OG0000203           NaN
# ..         ...           ...
# 287  OG0010973           NaN
# 288  OG0010974           NaN
# 289  OG0010975           NaN
# 290  OG0010976           NaN
# 291  OG0010977           NaN
#
#                                      Anopheles_gambiae  \
# 0    AGAP029136-PA, AGAP029137-PA, AGAP029162-PA, A...
# 1                                        AGAP005919-PA
# 2    AGAP010991-PA, AGAP010992-PA, AGAP010993-PA, A...
# 3    AGAP011978-PA, AGAP011979-PA, AGAP011989-PA, A...
# 4                                        AGAP029488-PB
# ..                                                 ...
# 287                                      AGAP000854-PA
# 288                                      AGAP013046-PA
# 289                                      AGAP013390-PA
# 290                                      AGAP013437-PA
# 291                       AGAP013495-PA, AGAP013495-PB
#
#                                 Culex_quinquefasciatus  \
# 0    CPIJ002010-PA, CPIJ002018-PA, CPIJ005520-PA, C...
# 1    CPIJ000748-PA, CPIJ001829-PA, CPIJ002217-PA, C...
# 2                                                  NaN
# 3    CPIJ001168-PA, CPIJ005004-PA, CPIJ006291-PA, C...
# 4          CPIJ003236-PA, CPIJ015331-PA, CPIJ019840-PA
# ..                                                 ...
# 287                                      CPIJ017399-PA
# 288                                      CPIJ009538-PA
# 289                                                NaN
# 290                                      CPIJ010703-PA
# 291                                                NaN
#
#                                Drosophila_melanogaster  \
# 0                                                  NaN
# 1                                                  NaN
# 2                             FBpp0090977, FBpp0304162
# 3                                                  NaN
# 4    FBpp0111616, FBpp0111618, FBpp0111619, FBpp029...
# ..                                                 ...
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
#
#                                       Wyeomyia_smithii  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    maker-tig00009456|arrow-exonerate_est2genome-g...
# ..                                                 ...
# 287                                                NaN
# 288                                                NaN
# 289  maker-tig00000654|arrow-exonerate_est2genome-g...
# 290                                                NaN
# 291                                                NaN
#
#                                               Function
# 0    [['-', 'IONOTROPIC RECEPTOR 20A-RELATED'], ['-...
# 1    [['consensus disorder prediction', 'Formin hom...
# 2    [['UNCHARACTERIZED', 'Protein of unknown funct...
# 3    [['7tm Odorant receptor', 'ODORANT RECEPTOR', ...
# 4    [['Calponin homology (CH) domain', 'consensus ...
# ..                                                 ...
# 287  [['G-protein coupled receptors family 1 signat...
# 288  [['consensus disorder prediction'], ['consensu...
# 289  [['consensus disorder prediction', 'Coil'], ['...
# 290  [['Coil', 'consensus disorder prediction'], ['...
# 291  [['consensus disorder prediction', 'FL(2)D-ASS...
#
# [292 rows x 7 columns]

# %%
OrthoGroup_GeneName_PresentAG = getMissingOrthogroup(OrthoGroup_GeneName_AA, OrthoGroup_GeneName_IntAG)
OrthoGroup_GeneName_AG = pd.merge(OrthoGroup_GeneName_AA, OrthoGroup_GeneName_PresentAG, on= 'Orthogroup')
OrthoGroup_GeneName_AG
# Out:
#     Orthogroup Aedes_aegypti Anopheles_gambiae  \
# 0    OG0000000           NaN               NaN
# 1    OG0000010           NaN               NaN
# 2    OG0000029           NaN               NaN
# 3    OG0000042           NaN               NaN
# 4    OG0000046           NaN               NaN
# ..         ...           ...               ...
# 633  OG0011105           NaN               NaN
# 634  OG0011106           NaN               NaN
# 635  OG0011107           NaN               NaN
# 636  OG0011108           NaN               NaN
# 637  OG0011109           NaN               NaN
#
#                           Culex_quinquefasciatus  \
# 0                                  CPIJ003781-PA
# 1    CPIJ014066-PA, CPIJ017401-PA, CPIJ017423-PA
# 2                                  CPIJ003782-PA
# 3                                  CPIJ007606-PA
# 4                                            NaN
# ..                                           ...
# 633                                          NaN
# 634                                          NaN
# 635                                          NaN
# 636                                          NaN
# 637                                          NaN
#
#                                Drosophila_melanogaster  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    FBpp0072260, FBpp0072261, FBpp0072283, FBpp008...
# ..                                                 ...
# 633                                                NaN
# 634                                                NaN
# 635                                                NaN
# 636                                                NaN
# 637                                                NaN
#
#                                       Wyeomyia_smithii
# 0    maker-tig00000051|arrow-exonerate_est2genome-g...
# 1    maker-tig00001022|arrow-exonerate_est2genome-g...
# 2    maker-tig00000321|arrow-exonerate_est2genome-g...
# 3    maker-tig00000213|arrow-exonerate_est2genome-g...
# 4                                                  NaN
# ..                                                 ...
# 633  maker-tig00001261|arrow-exonerate_est2genome-g...
# 634  maker-tig00055620|arrow-exonerate_est2genome-g...
# 635  maker-tig00031758|arrow-exonerate_est2genome-g...
# 636  maker-tig00267066|arrow-exonerate_est2genome-g...
# 637  maker-tig00031038|arrow-exonerate_est2genome-g...
#
# [638 rows x 6 columns]

# %%
Culex_quinquefasciatus = pd.read_excel("Culex_quinquefasciatus.xlsx")
#Culex_quinquefasciatus
Culex_quinquefasciatus = Culex_quinquefasciatus.drop("Unnamed: 0", 1)
Culex_quinquefasciatus
Culex_quinquefasciatus_dict = {}

for i in range(len(Culex_quinquefasciatus)):
    Culex_quinquefasciatus_dict[Culex_quinquefasciatus[0][i]] = Culex_quinquefasciatus[1][i]
    
Culex_quinquefasciatus_dict
# Out:
# {'CPIJ014113-PA': '["5\'-nucleotidase (syn. UDP-sugar hydrolase), C-terminal domain", "5\'-nucleotidase, C-terminal domain", \'MPP_CG11883_N\', \'-\', "5\'-NUCLEOTIDASE-RELATED", \'Apyrase family signature\', \'Calcineurin-like phosphoesterase\', \'RIKEN CDNA 4933425L06\', \'Metallo-dependent phosphatases\']',
#  'CPIJ010399-PA': "['ubx_3', 'consensus disorder prediction', 'UBA_UBXN1', 'UBA/TS-N domain', 'uba_6', 'UBX domain profile.', 'UBX DOMAIN-CONTAINING PROTEIN 1', 'UBX domain', 'DNA helicase RuvA subunit', 'Zinc finger C2H2 type domain signature.', 'Classic Zinc Finger', 'Zinc finger C2H2 type domain profile.', 'Ubiquitin-associated domain (UBA) profile.', '-', 'Coil', 'Ubiquitin-like', 'UBA-like']",
#  'CPIJ011301-PA': "['CUB domain', 'Serine proteases, trypsin domain profile.', 'trypsin_2', '-', 'Trypsin-like serine proteases', 'Serine proteases, trypsin family, histidine active site.', 'CUB', 'Trypsin', 'CUB domain profile.', 'Tryp_SPc', 'TRYPTASE-RELATED', 'CUB_2', 'Chymotrypsin serine protease family (S1) signature', 'Spermadhesin, CUB domain', 'AGAP011910-PA']",
#  'CPIJ017300-PA': "['Inosine-uridine preferring nucleoside hydrolase', 'Nucleoside hydrolase', '-', 'SI:CH211-201H21.5-RELATED', 'nuc_hydro_CeIAG']",
#  'CPIJ006562-PA': "['consensus disorder prediction', 'OB FOLD NUCLEIC ACID BINDING PROTEIN-RELATED', 'SoSSB_OBF', 'Nucleic acid-binding proteins', '-', 'SOSS COMPLEX SUBUNIT B1']",
#  'CPIJ010708-PA': "['PK beta-barrel domain-like', 'MOLYBDOPTERIN COFACTOR SULFURASE  MOSC', 'MOSC domain profile.', 'MOSC domain', 'MOSC N-terminal beta barrel domain', 'MOSC N-terminal domain-like', 'MITOCHONDRIAL AMIDOXIME-REDUCING COMPONENT 1']",
#  'CPIJ006192-PA': "['consensus disorder prediction', 'Plus-3 domain', 'Coil', 'rtf1', 'UNCHARACTERIZED', 'RNA POLYMERASE-ASSOCIATED PROTEIN RTF1 HOMOLOG', '-', 'Plus3-like', 'Plus3 domain profile.']",
#  'CPIJ017682-PA': "['Cytochrome Bc1 Complex; Chain A', 'CYTOCHROME B-C1 COMPLEX SUBUNIT 1, MITOCHONDRIAL', 'Peptidase M16 inactive domain', 'METALLOPROTEASE']",
#  'CPIJ005663-PA': "['consensus disorder prediction', '-', 'Beta_Casp_2', 'Metallo-hydrolase/oxidoreductase', 'INTEGRATOR COMPLEX SUBUNIT 9', 'Metallo-beta-lactamase superfamily domain']",
#  'CPIJ006770-PA': "['SIS_GlmS_GlmD_1', 'SIS domain profile.', 'Glutamine amidotransferase type 2 domain profile.', 'SIS domain', '-', 'glmS: glutamine-fructose-6-phosphate transaminase (isomerizing)', 'N-terminal nucleophile aminohydrolases (Ntn hydrolases)', 'SIS_GlmS_GlmD_2', 'GLUTAMINE--FRUCTOSE-6-PHOSPHATE AMINOTRANSFERASE [ISOMERIZING] 2', 'GLUCOSAMINE--FRUCTOSE-6-PHOSPHATE AMINOTRANSFERASE, ISOMERIZING', 'Glutamine amidotransferase domain', 'GFAT']",
#  'CPIJ006769-PA': "['SIS_GlmS_GlmD_1', 'SIS domain profile.', 'Glutamine amidotransferase type 2 domain profile.', 'SIS domain', '-', 'glmS: glutamine-fructose-6-phosphate transaminase (isomerizing)', 'N-terminal nucleophile aminohydrolases (Ntn hydrolases)', 'SIS_GlmS_GlmD_2', 'GLUTAMINE--FRUCTOSE-6-PHOSPHATE AMINOTRANSFERASE [ISOMERIZING] 2', 'GLUCOSAMINE--FRUCTOSE-6-PHOSPHATE AMINOTRANSFERASE, ISOMERIZING', 'Glutamine amidotransferase domain', 'GFAT']",
#  'CPIJ015003-PA': "['-', 'WD40_4', 'Trp-Asp (WD) repeats profile.', 'WD40 repeat-like', 'WD domain, G-beta repeat', 'Trp-Asp (WD) repeats circular profile.']",
#  'CPIJ010741-PA': "['-', 'HAD-hyrolase-like', 'Coil', 'HAD-like', 'PGP-type_phosphatase', 'RE04130P-RELATED', 'HAD-SF-IIA: HAD hydrolase, family IIA', 'Haloacid dehalogenase-like hydrolase', '4-NITROPHENYLPHOSPHATASE-RELATED']",
#  'CPIJ017158-PA': "['-', 'Zc3h12a-like Ribonuclease NYN domain', 'N4BP1-RELATED']",
#  'CPIJ001169-PA': "['Leucine-rich repeat profile.', 'consensus disorder prediction', 'Immunoglobulin I-set domain', 'IG(IMMUNOGLOBULIN) AND LRR(LEUCINE RICH REPEAT) DOMAINS', 'KEK6, ISOFORM B', 'IG_3c', 'Ig', 'Immunoglobulin', 'lrrct1', 'Immunoglobulins', 'Ig-like domain profile.', 'LRR_typ_2', 'Leucine rich repeat', 'igc2_5', 'L domain-like', 'Ribonuclease Inhibitor']",
#  'CPIJ006790-PA': '[\'consensus disorder prediction\', "\'Homeobox\' domain profile.", \'HOMEOBOX PROTEIN\', \'homeodomain\', \'HOX_1\', \'Homeodomain\', \'Homeodomain-like\', \'HOMEOTIC PROTEIN OCELLILESS\']',
#  'CPIJ009226-PA': "['consensus disorder prediction', 'Trp-Asp (WD) repeats profile.', 'TRANSDUCIN-LIKE ENHANCER PROTEIN 2', 'WD40', 'Groucho/transducin-like enhancer protein signature', 'Trp-Asp (WD) repeats circular profile.', 'WD domain, G-beta repeat', 'Trp-Asp (WD) repeats signature.', 'WD40_4', '-', 'Coil', 'Groucho/TLE N-terminal Q-rich domain', 'TRANSDUCIN-LIKE ENHANCER PROTEIN', 'WD40 repeat-like']",
#  'CPIJ012348-PA': '["3\'-5\' EXONUCLEASE ERI1-RELATED", \'Ribonuclease H-like\', "ERI-1_3\'hExo_like", \'-\', \'exoiiiendus\', \'Exonuclease\']',
#  'CPIJ010965-PA': "['consensus disorder prediction', 'SERINE/THREONINE-PROTEIN PHOSPHATASE 1 REGULATORY SUBUNIT 10', 'TFIIS N-terminal domain profile.', 'SERINE/THREONINE-PROTEIN PHOSPHATASE 1 REGULATORY SUBUNIT 10-RELATED', 'Conserved domain common to transcription factors TFIIS', 'TFIIS helical bundle-like domain', 'Conserved domain common to transcription factors TFIIS, elongin A, CRSP70']",
#  'CPIJ006025-PA': "['Domain of unknown function (DUF4781)', 'UNCHARACTERIZED']",
#  'CPIJ003218-PA': "['consensus disorder prediction', 'Peptidase_C19D', 'RING/U-box', 'Ubiquitin specific protease (USP) domain signature 2.', 'Zn-finger in ubiquitin-hydrolases and other protein', 'Zinc/RING finger domain', 'Ubiquitin specific protease (USP) domain profile.', 'UBIQUITIN CARBOXYL-TERMINAL HYDROLASE', 'Zinc finger UBP-type profile.', 'Ubiquitin specific protease (USP) domain signature 1.', 'UBIQUITIN CARBOXYL-TERMINAL HYDROLASE 22', 'Ubiquitin carboxyl-terminal hydrolase', 'Cysteine proteinases']",
#  'CPIJ006717-PA': "['Coil', 'consensus disorder prediction']",
#  'CPIJ003400-PA': "['RRM_SF', 'Eukaryotic RNA Recognition Motif (RRM) profile.', 'RNA-binding domain, RBD', 'RNA recognition motif. (a.k.a. RRM, RBD, or RNP domain)', 'rrm1_1', '-']",
#  'CPIJ008047-PA': "['consensus disorder prediction', 'Vesicle coat trafficking protein Sec16 mid-region']",
#  'CPIJ005154-PA': "['-', 'Nuclear transport factor 2 domain profile.', 'NTF2-like']",
#  'CPIJ012175-PA': "['consensus disorder prediction']",
#  'CPIJ008543-PA': "['consensus disorder prediction', 'beta-beta-alpha zinc fingers', 'Classic Zinc Finger', 'Zinc finger C2H2 type domain signature.', 'Zinc finger C2H2 type domain profile.', 'BLOODY FINGERS-RELATED', 'Zinc finger, C2H2 type', 'c2h2final6', 'KRAB AND ZINC FINGER DOMAIN-CONTAINING', 'C2H2-type zinc finger', 'Zinc-finger of C2H2 type', 'Coil']",
#  'CPIJ017111-PA': "['BolA-like protein', 'BolA-like', '-', 'BOLA-LIKE PROTEIN 3']",
#  'CPIJ017123-PA': "['MYOSIN REGULATORY LIGHT CHAIN 2', 'EF-hand domain', 'consensus disorder prediction', 'EF-hand calcium-binding domain profile.', '-', 'EF-hand calcium-binding domain.', 'EF-hand', 'efh_1']",
#  'CPIJ002538-PA': "['E-class P450 group I signature', 'Cytochrome P450', 'Cytochrome P450 cysteine heme-iron ligand signature.', 'CYTOCHROME P450 308A1-RELATED', 'CYTOCHROME P450', 'Cytochrome p450', 'P450 superfamily signature']",
#  'CPIJ017800-PA': "['PROTEIN CBG20215', 'PROTEIN CBG20215-RELATED']",
#  'CPIJ011116-PA': "['consensus disorder prediction', 'YTH  YT521-B HOMOLOGY  DOMAIN-CONTAINING', 'YTH domain profile.', 'YTH DOMAIN-CONTAINING FAMILY PROTEIN', 'YT521-B-like domain', 'ph1033 like domains']",
#  'CPIJ009429-PA': "['EF hand', '-', 'EF-hand', 'Zinc finger ZZ-type signature.', 'zz_5', 'E3 UBIQUITIN-PROTEIN LIGASE KCMF1', 'ZZ_dah', 'Zinc finger ZZ-type profile.', 'Zinc finger, ZZ type', 'DISCONTINUOUS ACTIN HEXAGON', 'Coil', 'RING/U-box']",
#  'CPIJ006712-PA': "['-', 'consensus disorder prediction', 'Pterin 4 alpha carbinolamine dehydratase', 'PTERIN-4-ALPHA-CARBINOLAMINE DEHYDRATASE', 'PCD_DCoH_subfamily_b', 'PCD-like']",
#  'CPIJ015325-PA': "['AAA+ lid domain', 'AAA', 'ATPASE FAMILY PROTEIN 2 HOMOLOG', 'Coil', 'AAA_5', 'AAA-protein family signature.', 'ATPase family associated with various cellular activities (AAA)', 'P-loop containing nucleoside triphosphate hydrolases', '-', 'AAA-FAMILY ATPASE']",
#  'CPIJ014482-PA': "['DYNEIN HEAVY CHAIN FAMILY PROTEIN', 'CYTOPLASMIC DYNEIN HEAVY CHAIN 1', 'P-loop containing dynein motor region D4', '-']",
#  'CPIJ003103-PA': "['SCAVENGER RECEPTOR CLASS B TYPE-1  SR-B1', 'FI02050P-RELATED', 'CD36 family', 'Adhesion molecule CD36 family signature']",
#  'CPIJ007162-PA': "['PGRP', 'N-acetylmuramoyl-L-alanine amidase-like', 'N-acetylmuramoyl-L-alanine amidase', 'ami_2', 'PGRP-S', 'Lysozyme', 'PEPTIDOGLYCAN RECOGNITION PROTEIN', 'pgrp']",
#  'CPIJ012920-PA': "['F-box domain', '-', 'F-BOX ONLY PROTEIN 48-RELATED', 'consensus disorder prediction', 'TPR repeat profile.', 'F-BOX ONLY PROTEIN 9', 'F-box domain profile.', 'F-box-like', 'TPR repeat region circular profile.']",
#  'CPIJ016649-PA': "['FAS-ASSOCIATED FACTOR 2', 'Ubiquitin-like', '45neu3', 'DNA helicase RuvA subunit', 'UBX domain profile.', 'consensus disorder prediction', 'FAS-ASSOCIATED PROTEIN', '-', 'UBA-like domain', 'UBX domain', 'UBX_UBXN3B', 'Thioredoxin-like', 'ubx_3', 'Coil', 'Glutaredoxin']",
#  'CPIJ001999-PA': "['NADH-UBIQUINONE OXIDOREDUCTASE ASHI SUBUNIT', 'NADH-ubiquinone oxidoreductase ASHI subunit (CI-ASHI or NDUFB8)']",
#  'CPIJ007843-PA': "['Kazal-type serine protease inhibitor domain', 'consensus disorder prediction', 'SERINE-TYPE ENDOPEPTIDASE INHIBITOR', '-', 'KAZ1-TYPE SERINE PROTEASE INHIBITOR-LIKE PROTEIN TYPE EPSILON', 'Kazal-type serine protease inhibitors']",
#  'CPIJ016873-PA': "['Trehalose receptor', 'GUSTATORY RECEPTOR FOR SUGAR TASTE 61A-RELATED', 'GUSTATORY RECEPTOR', 'GRP']",
#  'CPIJ014971-PA': "['TRANSMEMBRANE CHANNEL-LIKE PROTEIN 7', 'Coil', 'TMC domain', 'TRANSMEMBRANE CHANNEL-RELATED']",
#  'CPIJ015311-PA': "['DUMPY, ISOFORM Q', 'EGF-like domain signature 2.', 'EGF-like domain profile.', 'DPY module', 'Growth factor receptor domain', 'ENDOGLIN-RELATED', 'egf_5', 'ZP domain profile.', 'egfca_6', 'FOLN_3', 'PTI_1', 'zp_4']",
#  'CPIJ005184-PA': "['consensus disorder prediction']",
#  'CPIJ005756-PA': "['finulus', 'HLH, helix-loop-helix DNA-binding domain', 'HLH', 'Myc-type, basic helix-loop-helix (bHLH) domain profile.', 'consensus disorder prediction', 'orange_5', 'Orange domain profile.', 'Helix-loop-helix DNA-binding domain', 'Orange domain-like', 'Hairy Orange', 'BASIC HELIX-LOOP-HELIX TRANSCRIPTION FACTOR, HES-RELATED', 'PROTEIN DEADPAN-RELATED']",
#  'CPIJ003350-PA': "['consensus disorder prediction', 'Coil', 'XAP5, circadian clock regulator', 'XAP-5 PROTEIN-RELATED', 'PROTEIN FAM50A']",
#  'CPIJ006877-PA': "['Src homology 3 (SH3) domain profile.', 'consensus disorder prediction', 'SORBIN AND SH3 DOMAIN-CONTAINING PROTEIN 1', 'SH3 domain signature', 'SH3-domain', 'Spectrin alpha chain signature', 'Variant SH3 domain', 'SH3 domain', 'SH3 Domains', 'SH3_Sorbs_2', 'SH3_Sorbs_1', 'Coil', 'SH3_2', 'SH3 DOMAIN-CONTAINING']",
#  'CPIJ011139-PA': "['Zinc finger C2H2 type domain signature.', 'consensus disorder prediction', 'beta-beta-alpha zinc fingers', 'PROTEIN CBG18919', 'Zinc finger C2H2 type domain profile.', 'Classic Zinc Finger', 'B-CELL LYMPHOMA/LEUKEMIA 11', 'Zinc finger, C2H2 type', 'c2h2final6', 'Coil']",
#  'CPIJ017990-PA': "['-', 'trypsin_2', 'Chymotrypsin serine protease family (S1) signature', 'Trypsin', 'SERINE PROTEASE P96', 'Trypsin-like serine proteases', 'Tryp_SPc', 'Serine proteases, trypsin domain profile.', 'Serine proteases, trypsin family, histidine active site.', 'CHYMOTRYPSIN-RELATED', 'Serine proteases, trypsin family, serine active site.']",
#  'CPIJ016636-PA': "['RNase_H_like_Prp8_IV', 'MPN domain profile.', 'pad1_6', '-', 'JAB1/Mov34/MPN/PAD-1 ubiquitin protease', 'U6-snRNA interacting domain of PrP8', 'PRE-MRNA-PROCESSING-SPLICING FACTOR 8', 'U5-snRNA binding site 2 of PrP8', 'PROCN (NUC071) domain', 'Coil', 'PROCT (NUC072) domain', 'PRO8NT (NUC069), PrP8 N-terminal domain', 'Cytidine Deaminase', 'PRP8 domain IV core', 'PRE-MRNA SPLICING FACTOR PRP8', 'RNA recognition motif of the spliceosomal PrP8', 'MPN_PRP8', 'Ribonuclease H-like']",
#  'CPIJ014250-PA': "['consensus disorder prediction']",
#  'CPIJ011967-PA': "['BEAT-IV, ISOFORM B', 'Immunoglobulin', 'CD80-like C2-set immunoglobulin domain', 'Immunoglobulins', 'Ig-like domain profile.', 'BEAT PROTEIN']",
#  'CPIJ001735-PA': "['Coil', 'consensus disorder prediction', 'N-terminal region of Chorein or VPS13', 'UNCHARACTERIZED']",
#  'CPIJ019191-PA': "['Zinc finger C2H2 type domain profile.', 'zf_AD_2', 'Zinc finger C2H2 type domain signature.', 'beta-beta-alpha zinc fingers', 'Zinc finger, C2H2 type', 'Classic Zinc Finger', 'ZINC FINGER PROTEIN', 'Zinc-finger associated domain (zf-AD)', '-', 'Glucocorticoid receptor-like (DNA-binding domain)', 'c2h2final6']",
#  'CPIJ019584-PA': "['PROTEIN CBG11604', 'RE49668P']",
#  'CPIJ014410-PA': "['Cytochrome c', 'Cytochrome c family profile.', 'CYTOCHROME C1', 'Cytochrome c1 subunit of cytochrome bc1 complex (Ubiquinol-cytochrome c reductase), transmembrane anchor', 'Cytochrome C1 family', 'Cytochrome C1 signature', '-', 'CYTOCHROME C1, HEME PROTEIN, MITOCHONDRIAL']",
#  'CPIJ005022-PA': "['30S RIBOSOMAL PROTEIN S1', 'consensus disorder prediction', '-', 'Tex N-terminal region-like', 'Coil', 'Tex protein YqgF-like domain', 'S1 RNA-BINDING DOMAIN-CONTAINING PROTEIN 1', 'Ribonuclease H-like', 'Tex-like protein N-terminal domain', 'rnase_8s']",
#  'CPIJ013780-PA': "['STRUCTURAL CONTITUENT OF CUTICLE', 'Insect cuticle protein', 'CUTICULAR PROTEIN 35B', 'Insect cuticle protein signature', 'Chitin-binding type R&R domain profile.']",
#  'CPIJ010033-PA': "['-', 'consensus disorder prediction', '80 KDA MCM3-ASSOCIATED PROTEIN', 'SAC3/GANP family', 'LEUKOCYTE RECEPTOR CLUSTER MEMBER 8']",
#  'CPIJ010103-PA': "['consensus disorder prediction', 'BLOODY FINGERS-RELATED', 'beta-beta-alpha zinc fingers', 'KRAB AND ZINC FINGER DOMAIN-CONTAINING', 'Zinc finger C2H2 type domain profile.', 'Zinc finger C2H2 type domain signature.', 'Classic Zinc Finger', 'c2h2final6', 'Zinc-finger of C2H2 type', 'ZnF_U1_5']",
#  'CPIJ017475-PA': "['INNER MEMBRANE TRANSPORT PROTEIN YAJR', 'Major Facilitator Superfamily', 'MFS general substrate transporter', 'MFS_MFSD8', 'Major facilitator superfamily (MFS) profile.', 'MAJOR FACILITATOR SUPERFAMILY DOMAIN-CONTAINING PROTEIN 8']",
#  'CPIJ005076-PA': "['consensus disorder prediction', 'retropepsin_like_LTR_1', '-']",
#  'CPIJ016043-PA': "['E3 gp78 Ube2g2-binding region (G2BR)', 'CUE domain profile.', 'consensus disorder prediction', 'Ring finger domain', 'RING-H2_AMFR', 'CUE domain', 'E3 UBIQUITIN-PROTEIN LIGASE AMFR', 'ring_2', 'E3 UBIQUITIN-PROTEIN LIGASE RNF8', 'cue_7', 'RING/U-box', 'Zinc/RING finger domain', 'DNA helicase RuvA subunit', 'Zinc finger RING-type profile.', 'CUE_AMFR']",
#  'CPIJ009092-PA': "['Calcium-activated chloride channel N terminal', 'vWA-like', 'consensus disorder prediction', 'CALCIUM-ACTIVATED CHLORIDE CHANNEL REGULATOR', 'Coil', '-', 'vWFA']",
#  'CPIJ000325-PA': "['-', 'Prim-pol domain', 'DNA primase small subunit', 'primase_sml: putative DNA primase, eukaryotic-type, small subunit', 'DNA PRIMASE SMALL SUBUNIT', 'AE_Prim_S']",
#  'CPIJ000684-PA': "['UNCHARACTERIZED', 'TRNA(HIS) GUANYLYLTRANSFERASE-RELATED', 'Thg1 C terminal domain', 'tRNAHis guanylyltransferase', '-']",
#  'CPIJ011899-PA': "['-', '40S RIBOSOMAL PROTEIN S3', 'Ribosomal protein S3 C-terminal domain', '30S/40S RIBOSOMAL PROTEIN S3']",
#  'CPIJ003515-PA': "['DHHC domain profile.', 'ZINC FINGER DHHC DOMAIN CONTAINING PROTEIN', 'PALMITOYLTRANSFERASE ZDHHC3', 'DHHC palmitoyltransferase']",
#  'CPIJ005275-PA': "['EUKARYOTIC TRANSLATION INITIATION FACTOR 2C', 'Piwi domain', 'Argonaute linker 1 domain', 'PAZ domain', 'PAZ_2_a_3', 'PAZ domain profile.', '-', 'consensus disorder prediction', 'PIWI-LIKE PROTEIN 2', 'Piwi_piwi-like_Euk', 'Ribonuclease H-like', 'PAZ_piwi_like', 'Piwi_a_2', 'Piwi domain profile.', 'paz domain']",
#  'CPIJ016657-PB': "['Glucose/ribitol dehydrogenase family signature', 'short chain dehydrogenase', '-', 'Short-chain dehydrogenase/reductase (SDR) superfamily signature', 'This enzymatic domain is part of bacterial polyketide synthases and catalyses the first step in the reductive modification of the beta-carbonyl centres in the growing polyketide chain. It uses NADPH to reduce the keto group to a hydroxy group.', 'PKSB', 'NAD(P)-binding Rossmann-fold domains']",
#  'CPIJ001503-PA': "['-', 'IONOTROPIC RECEPTOR 68A, ISOFORM A', 'IONOTROPIC RECEPTOR 20A-RELATED', 'Periplasmic binding protein-like II']",
#  'CPIJ014957-PA': "['consensus disorder prediction', 'AGAP001705-PA', 'AGAP000266-PA']",
#  'CPIJ015441-PA': "['Inhibitor of apoptosis-promoting Bax1', 'BAX INHIBITOR-RELATED', 'LFG_like', 'consensus disorder prediction', 'X-BOX PROMOTER ELEMENT REGULATED']",
#  'CPIJ014751-PA': "['Zinc-finger of RNA-polymerase I-specific TFIIB, Rrn7', 'TATA BOX-BINDING PROTEIN-ASSOCIATED FACTOR RNA POLYMERASE I SUBUNIT B', 'consensus disorder prediction']",
#  'CPIJ002679-PA': "['GST_N_Delta_Epsilon', 'Soluble glutathione S-transferase N-terminal domain profile.', 'Soluble glutathione S-transferase C-terminal domain profile.', 'Thioredoxin-like', 'GST_C_Delta_Epsilon', '-', 'Glutaredoxin', 'Glutathione S-transferase, N-terminal domain', 'GLUTATHIONE S TRANSFERASE D10, ISOFORM A-RELATED', 'GST C-terminal domain-like', 'Glutathione S-transferase, C-terminal domain', 'Main.4: Theta-like', 'Main (cytGST)']",
#  'CPIJ001426-PA': "['Zinc finger RING-type profile.', 'Zinc finger B-box type profile.', 'B-box zinc-binding domain', 'B-box zinc finger', '-', 'Coil', 'Zinc/RING finger domain', 'RING/U-box', 'E3 UBIQUITIN-PROTEIN LIGASE TRIM37', 'Bbox2']",
#  'CPIJ011039-PA': "['GH04538P', 'AMINO ACID TRANSPORTER', 'Transmembrane amino acid transporter protein']",
#  'CPIJ015823-PA': "['PROTEIN PITCHFORK']",
#  'CPIJ001639-PA': "['-', 'FLYWCH zinc finger domain']",
#  'CPIJ013609-PA': "['Myofilin']",
#  'CPIJ006068-PA': "['UGPase_euk', 'UTP--GLUCOSE-1-PHOSPHATE URIDYLYLTRANSFERASE', 'UTP--glucose-1-phosphate uridylyltransferase', 'Nucleotide-diphospho-sugar transferases', 'Spore Coat Polysaccharide Biosynthesis Protein SpsA; Chain A', 'Hexapeptide repeat proteins', '-', 'UDPGP']",
#  'CPIJ009172-PA': "['Cysteine proteinases', 'Ubiquitin specific protease (USP) domain signature 1.', 'consensus disorder prediction', 'Ubiquitin specific protease (USP) domain profile.', 'UBIQUITIN CARBOXYL-TERMINAL HYDROLASE', 'Ubiquitin carboxyl-terminal hydrolase']",
#  'CPIJ012415-PA': "['Histone', 'HISTONE H2A', 'Histone-fold']",
#  'CPIJ019111-PA': "['7tmB3_Methuselah-like', 'G-PROTEIN COUPLED RECEPTOR MTH-LIKE 1-RELATED', 'consensus disorder prediction', '7 transmembrane receptor (Secretin family)', '-', 'Coil']",
#  'CPIJ002006-PA': "['Formin homology 2 domain (FH2 domain)', 'ARM repeat', '-', 'Drf_GBD_2', 'Diaphanous FH3 Domain', 'Drf_FH3_2', 'Formin Homology 2 Domain', 'Diaphanous GTPase-binding Domain', 'Formin homology-2 (FH2) domain profile.', 'DISHEVELED-ASSOCIATED ACTIVATOR OF MORPHOGENESIS 2', 'Rho GTPase-binding/formin homology 3 (GBD/FH3) domain profile.', 'FORMIN HOMOLOGY 2 FAMILY MEMBER', 'Coil', 'consensus disorder prediction']",
#  'CPIJ001885-PA': "['consensus disorder prediction']",
#  'CPIJ005460-PA': "['BEAT PROTEIN', 'BEATEN PATH IA, ISOFORM B-RELATED']",
#  'CPIJ007886-PA': "['LRR_CC_2', 'RNI-like', 'consensus disorder prediction', 'Ribonuclease Inhibitor']",
#  'CPIJ019514-PA': "['CYCLIC NUCLEOTIDE-GATED CATION CHANNEL SUBUNIT A', 'Voltage-gated potassium channels']",
#  'CPIJ002520-PA': "['Trp-Asp (WD) repeats profile.', '-', 'Trp-Asp (WD) repeats signature.', 'WD40 repeat-like', 'WD40', 'GUANINE NUCLEOTIDE-BINDING PROTEIN BETA  G PROTEIN BETA', 'Coil', 'Beta G protein (transducin) signature', 'GNBP_B', 'WD40_4', 'G protein beta WD-40 repeat signature', 'WD domain, G-beta repeat', 'Trp-Asp (WD) repeats circular profile.', 'GUANINE NUCLEOTIDE-BINDING PROTEIN SUBUNIT BETA-5']",
#  'CPIJ018949-PA': "['consensus disorder prediction', 'Zinc finger C2H2 type domain profile.', 'Zinc finger C2H2 type domain signature.', 'Classic Zinc Finger', 'Zinc finger, C2H2 type', 'ZINC FINGER PROTEIN ZIC AND GLI', 'beta-beta-alpha zinc fingers', 'Zic proteins zinc finger domain', 'c2h2final6', 'PAIR-RULE PROTEIN ODD-PAIRED']",
#  'CPIJ010123-PA': "['KU_2', 'Kunitz/Bovine pancreatic trypsin inhibitor domain', '-', 'Thrombospondin type-1 (TSP1) repeat profile.', 'Thrombospondin type 1 domain', 'Pancreatic trypsin inhibitor (Kunitz) family profile.', 'FAT-SPONDIN', 'TSP-1 type 1 repeat', 'Spondin domain profile.', 'Basic protease (Kunitz-type) inhibitor family signature', 'Reelin domain profile.', 'Reeler', 'KU', 'Pancreatic trypsin inhibitor (Kunitz) family signature.', 'SPONDIN', 'Reeler domain', 'Factor Xa Inhibitor', 'consensus disorder prediction', 'Spondin-like TSP1 domain', 'TSP1_2', 'Spondin_N', 'BPTI-like']",
#  'CPIJ003210-PA': "['WD40 repeat-like', '-']",
#  'CPIJ012520-PA': "['RNA-binding domain, RBD', 'G-patch domain profile.', '-', 'SPF45', 'RRM_UHM_SPF45', 'Eukaryotic RNA Recognition Motif (RRM) profile.', 'RNA recognition motif. (a.k.a. RRM, RBD, or RNP domain)', 'G-patch domain', 'rrm2_1', 'consensus disorder prediction', 'SPLICING FACTOR 45 SPF45', 'G-patch_5']",
#  'CPIJ013099-PA': "['consensus disorder prediction']",
#  'CPIJ008839-PA': "['consensus disorder prediction', 'CC2D2A N-terminal C2 domain', 'Coil', 'C2 domain profile.', 'CENTROSOMAL PROTEIN-RELATED', '-', 'C2 domain (Calcium/lipid-binding domain, CaLB)', 'C2_3c', 'C2 domain']",
#  'CPIJ014206-PA': "['arf_sub_2', 'small GTPase Arf family profile.', 'ADP-RIBOSYLATION FACTOR 6', 'rab_sub_5', '-', 'small_GTP: small GTP-binding protein domain', 'ADP-ribosylation factor family', 'ADP RIBOSYLATION FACTOR-RELATED', 'P-loop containing nucleoside triphosphate hydrolases', 'GTP-binding SAR1 protein signature', 'sar_sub_1', 'Arf6']",
#  'CPIJ002559-PA': "['consensus disorder prediction', '-', 'BSD domain profile.', 'SYNAPSE-ASSOCIATED PROTEIN 1', 'Coil', 'BSD domain-like', 'wurzfinal6', 'BSD domain', 'SYNAPSE-ASSOCIATED PROTEIN']",
#  'CPIJ002501-PA': "['Phospholipase A2', 'Phospholipase A2 histidine active site.', 'Phospholipase A2, PLA2']",
#  'CPIJ018517-PA': "['PHD_SF', 'FYVE/PHD zinc finger', 'Coil', 'Zinc/RING finger domain']",
#  'CPIJ003954-PA': "['Invertebrate chitin-binding proteins', 'Chitin-binding type-2 domain profile.', 'Chitin binding Peritrophin-A domain', 'CHITIN BINDING PERITROPHIN-A', 'Antimicrobial Protein', 'chi_10', 'IP16275P-RELATED', 'Glycosidases']",
#  'CPIJ005779-PA': "['ATP-citrate lyase / succinyl-CoA ligases family signature 3.', '-', 'sucCoAbeta: succinate-CoA ligase, beta subunit', 'SucCS_beta', 'Succinyl-CoA synthetase domains', 'SUCCINYL-COA SYNTHETASE BETA CHAIN', 'SUCCINATE--COA LIGASE [GDP-FORMING] SUBUNIT BETA, MITOCHONDRIAL', 'CoA-ligase', 'Glutathione synthetase ATP-binding domain-like', 'ATP-grasp domain']",
#  'CPIJ017566-PA': "['MFS general substrate transporter', 'SOLUTE CARRIER FAMILY 22 MEMBER', 'Sugar (and other) transporter', 'Major facilitator superfamily (MFS) profile.', 'AT15560P-RELATED']",
#  'CPIJ011660-PA': "['consensus disorder prediction', 'S-adenosyl-L-methionine-dependent methyltransferases', 'AdoMet_MTases', 'UbiG: 3-demethylubiquinone-9 3-O-methyltransferase', 'METHYLTRANSFERASE', 'Methyltransferase domain', 'UBIQUINONE BIOSYNTHESIS O-METHYLTRANSFERASE, MITOCHONDRIAL', 'Vaccinia Virus protein VP39']",
#  'CPIJ001097-PA': "['consensus disorder prediction', 'PROTEIN SICKIE', 'STEERIN', 'Coil']",
#  'CPIJ018241-PA': "['MICROSOMAL GLUTATHIONE S-TRANSFERASE 1', '-', 'MAPEG domain-like', 'MAPEG family']",
#  'CPIJ016949-PA': "['PBP/GOBP family', 'Insect pheromone/odorant-binding proteins', 'GENERAL ODORANT-BINDING PROTEIN 19A', 'phbp', '-', 'UNCHARACTERIZED']",
#  'CPIJ000882-PA': "['consensus disorder prediction']",
#  'CPIJ001987-PA': "['SERINE/THREONINE-PROTEIN PHOSPHATASE', 'SERINE/THREONINE PROTEIN PHOSPHATASE', 'Serine/threonine phosphatase family signature', 'pp2a_7', 'Calcineurin-like phosphoesterase', 'Metallo-dependent phosphatases', 'Serine/threonine specific protein phosphatases signature.', 'MPP_PP1_PPKL', 'consensus disorder prediction', 'Serine-threonine protein phosphatase N-terminal domain', '-']",
#  'CPIJ011236-PA': "['SH2_nSH2_p85_like', 'RhoGAP_3', 'SH2 domain', 'Src homology 2 (SH2) domain profile.', 'Cysteine-rich domain', 'SH2_5', 'PI3 kinase P85 regulatory subunit signature', 'consensus disorder prediction', 'SHC Adaptor Protein', 'Rho GTPase-activating proteins domain profile.', 'GTPase activation domain, GAP', 'PHOSPHATIDYLINOSITOL 3-KINASE REGULATORY SUBUNIT', 'iSH2_PI3K_IA_R', 'RhoGAP', 'C1', 'Coil', 'RhoGAP domain', 'Zinc finger phorbol-ester/DAG-type profile.', 'Phosphatidylinositol 3-kinase regulatory subunit P85 inter-SH2 domain', 'PI3K21B, ISOFORM B', 'c1_12', 'Zinc finger phorbol-ester/DAG-type signature.', '-', 'SH2 domain signature', 'Phorbol esters/diacylglycerol binding domain (C1 domain)']",
#  'CPIJ016551-PA': "['Caspase family cysteine active site.', 'CASPASE-RELATED', 'Caspase-like', 'Interleukin-1B converting enzyme signature', 'Caspase family p10 domain profile.', 'caspase_2', 'Caspase family p20 domain profile.', 'Caspase domain', 'CASPASE', '-']",
#  'CPIJ017630-PA': "['TBC1 DOMAIN FAMILY MEMBER GTPASE-ACTIVATING PROTEIN', 'TBC/rab GAP domain profile.', 'putative rabgap domain of human tbc1 domain family member 14 like domains', 'Ypt/Rab-GAP domain of gyp1p', 'consensus disorder prediction', 'Coil', 'tbc_4', 'USP6 N-TERMINAL-LIKE PROTEIN', 'Rab-GTPase-TBC domain', '-']",
#  'CPIJ017877-PA': "['FBG_2', 'FReD', 'Fibrinogen C-terminal domain-like', 'FIBRINOGEN/TENASCIN/ANGIOPOEITIN', 'Fibrinogen beta and gamma chains, C-terminal globular domain', '-', 'Fibrinogen C-terminal domain profile.']",
#  'CPIJ004501-PA': "['UNCHARACTERIZED', 'PRE-MRNA-SPLICING FACTOR 38B', 'consensus disorder prediction', 'PRP38 family']",
#  'CPIJ007188-PA': "['Cytochrome P450 cysteine heme-iron ligand signature.', 'Cytochrome p450', 'P450 superfamily signature', 'CYTOCHROME P450 FAMILY 4', 'E-class P450 group I signature', 'Cytochrome P450', 'CYTOCHROME P450 4D1-RELATED']",
#  'CPIJ000259-PA': "['INNEXIN', 'Pannexin family profile.', 'consensus disorder prediction', 'INNEXIN INX4-RELATED', 'Innexin signature', 'Innexin']",
#  'CPIJ001131-PA': "['SPFH domain / Band 7 family', 'STOMATIN-LIKE PROTEIN 2, MITOCHONDRIAL', 'PHB_4', 'SPFH_paraslipin', 'consensus disorder prediction', 'C-terminal region of band_7', '-', 'Band 7/SPFH domain', 'Stomatin signature']",
#  'CPIJ012112-PA': "['ENTH domain profile.', 'GAT-like domain', '-', 'PHOSPHATIDYLINOSITOL-BINDING CLATHRIN ASSEMBLY PROTEIN LAP', 'enth_2', 'ANTH domain', 'ENTH/VHS domain', 'CLATHRIN ASSEMBLY PROTEIN']",
#  'CPIJ019522-PA': "['consensus disorder prediction']",
#  'CPIJ001035-PA': "['Lipase', 'alpha/beta-Hydrolases', 'Pancreat_lipase_like', 'Triacylglycerol lipase family signature', 'FI01825P-RELATED', 'Vespid venom allergen phospholipase A1 signature', '-', 'LIPASE']",
#  'CPIJ006488-PA': "['consensus disorder prediction', 'FROUNT PROTEIN-RELATED', 'Nup85 Nucleoporin']",
#  'CPIJ007531-PA': "['consensus disorder prediction']",
#  'CPIJ016130-PA': "['BESTROPHIN', 'Bestrophin, RFP-TM, chloride channel', 'BESTROPHIN 2']",
#  'CPIJ000643-PA': "['metG: methionine--tRNA ligase', 'HUPs', 'Nucleotidylyl transferase', 'MetRS_core', '-', 'Methionyl-tRNA synthetase signature', 'METHIONYL-TRNA SYNTHETASE', 'Anticodon-binding domain of tRNA ligase', 'Anticodon-binding domain of a subclass of class I aminoacyl-tRNA synthetases', 'Anticodon_Ia_Met', 'tRNA synthetases class I (M)']",
#  'CPIJ013594-PA': "['consensus disorder prediction']",
#  'CPIJ012162-PA': "['Coil']",
#  'CPIJ002459-PA': "['paz domain', 'Piwi_a_2', 'consensus disorder prediction', 'PAZ domain', 'Piwi domain profile.', 'Ribonuclease H-like', 'Piwi domain', '-', 'Piwi_piwi-like_Euk', 'PAZ domain profile.', 'PIWI-LIKE PROTEIN 1', 'PAZ_piwi_like', 'EUKARYOTIC TRANSLATION INITIATION FACTOR 2C', 'PAZ_2_a_3']",
#  'CPIJ015414-PA': "['consensus disorder prediction']",
#  'CPIJ016455-PA': "['consensus disorder prediction', 'Coil']",
#  'CPIJ006561-PA': "['consensus disorder prediction', 'PEPTIDOGLYCAN RECOGNITION PROTEIN', 'Lysozyme', 'PGRP', 'pgrp', 'N-acetylmuramoyl-L-alanine amidase', 'PEPTIDOGLYCAN-RECOGNITION PROTEIN LF', 'ami_2', 'N-acetylmuramoyl-L-alanine amidase-like']",
#  'CPIJ014035-PA': "['Tudor domain profile.', 'Tudor/PWWP/MBT', '-', 'TUDOR_7', 'Tudor domain', 'TUDOR DOMAIN CONTAINING PROTEIN', 'TUDOR']",
#  'CPIJ012092-PA': "['POTASSIUM VOLTAGE-GATED CHANNEL, KQT-LIKE SUBFAMILY, MEMBER 1-RELATED', 'Voltage-gated potassium channels', 'VOLTAGE-GATED POTASSIUM CHANNEL', '-', 'KCNQ voltage-gated potassium channel family signature', 'consensus disorder prediction', 'Ion transport protein']",
#  'CPIJ012300-PA': "['consensus disorder prediction', 'DNA2/NAM7 HELICASE FAMILY', '1B_UPF1-like', 'RNA helicase (UPF2 interacting domain)', 'ZBD_UPF1-like', 'AAA domain', 'REGULATOR OF NONSENSE TRANSCRIPTS 1-LIKE PROTEIN', '-', 'SF1_C_Upf1', 'Domain of unknown function (DUF5599)', 'P-loop containing nucleoside triphosphate hydrolases', 'DEXXQc_UPF1']",
#  'CPIJ015361-PA': "['-', 'Laminin EGF domain', 'Laminin', 'EGF-like domain profile.', 'EGF-like domain signature 1.', 'EGF-like domain', 'C901', 'EGF_CA', 'EGF/Laminin', 'NOTCH LIGAND FAMILY MEMBER', 'DSL domain profile.', 'egf_5', 'EGF-like domain signature 2.']",
#  'CPIJ012997-PA': "['consensus disorder prediction', '-', 'ECDYSONE-INDUCED PROTEIN 93F, ISOFORM C', 'Homeodomain-like', 'Coil', 'TRANSCRIPTION FACTOR MLR1/2', 'Psq-type HTH domain profile.', 'helix-turn-helix, Psq domain']",
#  'CPIJ008627-PA': "['Coil', 'consensus disorder prediction']",
#  'CPIJ002405-PA': "['consensus disorder prediction', '-', 'PerC transcriptional activator', 'Coil']",
#  'CPIJ009359-PA': "['-', 'Invertebrate (I)-type lysozyme domain profile.', 'RH48616P', 'lyz_i', 'Destabilase', 'DESTABILASE-RELATED']",
#  'CPIJ020199-PA': "['CYTOCHROME P450', 'Group II E-class P450 signature', 'ABC-2 type transporter', 'Cytochrome P450', 'CYP6A16, ISOFORM B-RELATED', 'Cytochrome p450']",
#  'CPIJ018084-PA': "['Clavaminate synthase-like', 'cupin_9', 'LYSINE-SPECIFIC DEMETHYLASE', 'TPR-like', 'LYSINE-SPECIFIC DEMETHYLASE 6A', 'consensus disorder prediction', '-', 'TPR repeat region circular profile.', 'TPR repeat profile.', 'JmjC domain, hydroxylase', 'tpr_5', 'Cupin', 'JmjC domain profile.']",
#  'CPIJ009168-PA': "['N-Acetylglucosaminyltransferase-IV (GnT-IV) conserved region', 'N-ACETYLGLUCOSAMINYLTRANSFERASE VI', 'FI02046P']",
#  'CPIJ017774-PA': "['PHENYLALANYL-TRNA SYNTHETASE BETA CHAIN AND LEUCINE-RICH REPEAT-CONTAINING PROTEIN 47', '-']",
#  'CPIJ003368-PA': "['ADAMTS  A DISINTEGRIN AND METALLOPROTEASE WITH THROMBOSPONDIN MOTIFS  PROTEASE', 'consensus disorder prediction', 'NO LONG NERVE CORD, ISOFORM C']",
#  'CPIJ006219-PA': "['Phosphotyrosine interaction domain (PTB/PID)', 'Phosphotyrosine interaction domain (PID) profile.', 'SHC TRANSFORMING PROTEIN', 'PTB_9', 'PTB_Shc', '-', 'SH2 domain signature', 'SH2_SHC', 'DSHC PROTEIN', 'Src homology 2 (SH2) domain profile.', 'SH2 domain', 'SH2_5', 'SHC Adaptor Protein', 'SHC phosphotyrosine interaction domain signature', 'PH domain-like']",
#  'CPIJ009093-PA': "['PLPDE_III_ODC', 'Ornithine decarboxylase signature', 'Ornithine/diaminopimelate/arginine (ODA) decarboxylase family signature', 'PLP-binding barrel', 'Pyridoxal-dependent decarboxylase, C-terminal sheet domain', 'ARGININE/DIAMINOPIMELATE/ORNITHINE DECARBOXYLASE', 'Alanine racemase', 'Lyase', 'ORNITHINE DECARBOXYLASE 1-RELATED', 'Alanine racemase C-terminal domain-like', 'Pyridoxal-dependent decarboxylase, pyridoxal binding domain']",
#  'CPIJ015392-PA': "['-', 'Actin-like ATPase domain', 'Actin', 'ACTIN', 'NBD_sugar-kinase_HSP70_actin', 'ACTIN-RELATED PROTEIN 3', 'Actins and actin-related proteins signature.', 'Actin; Chain A', 'actin_3']",
#  'CPIJ015663-PA': "['ATILLA, ISOFORM B-RELATED-RELATED', 'Sleepless protein', 'FI02817P']",
#  'CPIJ007548-PA': "['Zinc/RING finger domain', 'PROTEIN JADE-1', 'PHD-finger', 'FYVE/PHD zinc finger', 'consensus disorder prediction', 'Enhancer of polycomb-like', 'PHD FINGER PROTEINS']",
#  'CPIJ012600-PA': "['Zinc finger C2H2 type domain profile.', 'Zinc finger C2H2 type domain signature.', 'beta-beta-alpha zinc fingers', 'Classic Zinc Finger', 'c2h2final6', 'Zinc finger, C2H2 type', 'IP01015P-RELATED', 'C2H2-type zinc finger', 'consensus disorder prediction', 'SI:DKEY-111K8.2-RELATED']",
#  'CPIJ011539-PA': "['Nicotinic acetylcholine receptor signature', 'Nicotinic receptor ligand binding domain-like', 'Neurotransmitter-gated ion-channel ligand binding domain', 'LGIC_ECD_nAChR_proto_alpha-like', 'NEUROTRANSMITTER GATED ION CHANNEL', 'Neurotransmitter-gated ion-channel transmembrane pore', 'Neurotransmitter-gated ion channel family signature', 'NICOTINIC ACETYLCHOLINE RECEPTOR ALPHA4, ISOFORM H', 'Glr4197 protein', '-', 'LIC: cation transporter family protein', 'Neurotransmitter-gated ion-channel transmembrane region', 'Neurotransmitter-gated ion-channels signature.', 'LGIC_TM_nAChR']",
#  'CPIJ002493-PA': "['Cation efflux family', 'consensus disorder prediction', 'LD05335P', '-', 'Cation efflux protein cytoplasmic domain-like', 'CATION EFFLUX PROTEIN/ ZINC TRANSPORTER', 'Cation efflux protein transmembrane domain-like', 'CDF: cation diffusion facilitator family transporter']",
#  'CPIJ002734-PA': "['Protein of unknown function (DUF1091)', 'UNCHARACTERIZED', 'CHEMOSENSORY PROTEIN A 29A-RELATED']",
#  'CPIJ011959-PA': "['ABC transporter transmembrane region', 'CANALICULAR MULTISPECIFIC ORGANIC ANION TRANSPORTER 1', 'ATP-BINDING CASSETTE SUB-FAMILY C', '-', 'ABC transporter integral membrane type-1 fused domain profile.']",
#  'CPIJ012638-PA': "['Nicotinic receptor ligand binding domain-like', 'Neurotransmitter-gated ion-channel ligand binding domain', '-', 'NEUROTRANSMITTER GATED ION CHANNEL', 'Neurotransmitter-gated ion channel family signature', 'LGIC_ECD_cation', 'ACETYLCHOLINE RECEPTOR SUBUNIT ALPHA-LIKE 2']",
#  'CPIJ005955-PA': "['P450 superfamily signature', 'CYTOCHROME P450', 'E-class P450 group I signature', 'Cytochrome p450', 'Cytochrome P450', 'CYP6A16, ISOFORM B-RELATED', 'Cytochrome P450 cysteine heme-iron ligand signature.']",
#  'CPIJ016024-PA': "['-', 'Zinc finger, C4 type (two domains)', 'C4-type steroid receptor zinc finger signature', 'Nuclear receptor (NR) ligand-binding (LBD) domain profile.', 'holi', 'Nuclear hormones receptors DNA-binding region signature.', 'NUCLEAR HORMONE RECEPTOR', 'Ligand-binding domain of nuclear hormone receptor', 'NR_LBD_RXR_like', 'Nuclear receptor ligand-binding domain', 'Nuclear hormone receptors DNA-binding domain profile.', 'Steroid hormone receptor signature', 'Glucocorticoid receptor-like (DNA-binding domain)', 'Retinoid X receptor signature', 'c4gold', 'Retinoid X Receptor', 'PROTEIN ULTRASPIRACLE', 'NR_DBD_RXR']",
#  'CPIJ040875-PA': "['Protein kinase domain', 'Transferase(Phosphotransferase) domain 1', 'Immunoglobulins', 'Ig-like domain profile.', 'Immunoglobulin', 'Fibronectin type-III domain profile.', 'Serine/Threonine protein kinases active-site signature.', 'serkin_6', 'IG_3c', 'Phosphorylase Kinase; domain 1', 'Immunoglobulin I-set domain', 'Protein kinase-like (PK-like)', 'Protein kinase domain profile.', 'Fibronectin type III', 'FN3', 'Protein kinases ATP-binding region signature.', 'Fibronectin type III domain', 'MYOSIN, LIGHT CHAIN KINASE 5', 'SERINE/THREONINE-PROTEIN KINASE', 'TyrPK_CSF1-R', 'FN3_2']",
#  'CPIJ009202-PA': "['consensus disorder prediction']",
#  'CPIJ000660-PA': "['consensus disorder prediction', 'PROTEIN TIMELESS HOMOLOG', 'TIMEOUT/TIMELESS-2', 'SANT', 'Timeless PAB domain']",
#  'CPIJ006381-PA': "['consensus disorder prediction', 'STKc_TTBK', 'serkin_6', 'Protein kinase domain', 'CASEIN KINASE-RELATED', 'Protein kinase domain profile.', 'Transferase(Phosphotransferase) domain 1', 'TAU-TUBULIN KINASE 1', 'Protein kinase-like (PK-like)']",
#  'CPIJ009114-PA': '[\'ANGIOTENSIN-CONVERTING ENZYME\', \'Angiotensin-converting enzyme\', \'Metalloproteases ("zincins"), catalytic domain\']',
#  'CPIJ000038-PA': "['Glycogen Phosphorylase B;', 'EG:EG0003.4 PROTEIN-RELATED', 'UDP-Glycosyltransferase/glycogen phosphorylase', 'GT1_Gtf-like', 'UDP-glucoronosyl and UDP-glucosyl transferase']",
#  'CPIJ019000-PA': '[\'consensus disorder prediction\', \'SIMIBI\', \'CLEAVAGE/POLYADENYLATION FACTOR IA SUBUNIT CLP1P\', \'mRNA cleavage and polyadenylation factor CLP1 P-loop\', \'P-loop containing nucleoside triphosphate hydrolases\', \'-\', "POLYNUCLEOTIDE 5\'-HYDROXYL-KINASE NOL9"]',
#  'CPIJ001367-PA': "['FAD-linked reductases, C-terminal domain', 'GMC oxidoreductases signature 2.', 'GMC oxidoreductase', 'GMC oxidoreductases signature 1.', '-', 'Alcohol_oxidase', 'consensus disorder prediction', 'Glucose Oxidase', 'GLUCOSE-METHANOL-CHOLINE  GMC  OXIDOREDUCTASE', 'FAD/NAD(P)-binding domain', 'FI02019P']",
#  'CPIJ018525-PA': "['Coil', 'consensus disorder prediction']",
#  'CPIJ001254-PA': "['Coil', 'GTP-BINDING PROTEIN-RELATED', 'consensus disorder prediction', 'NGP1NT (NUC091) domain', '-', 'P-loop containing nucleoside triphosphate hydrolases', 'NUCLEOLAR GTP-BINDING PROTEIN 2', 'GTP1/OBG GTP-binding protein family signature', '50S ribosome-binding GTPase', 'NGP_1', 'Ras_like_GTPase']",
#  'CPIJ018920-PA': "['Somatomedin B domain', 'Complement Module', 'Complement control module/SCR domain', 'consensus disorder prediction', 'CCP', 'Sushi repeat (SCR repeat)', '-', 'Sushi/CCP/SCR domain profile.', 'MAM', 'APICAL ENDOSOMAL GLYCOPROTEIN PRECURSOR.', 'Somatomedin B (SMB) domain profile.', 'RT07201P-RELATED', 'MAM domain, meprin/A5/mu', 'MAM_2', 'Concanavalin A-like lectins/glucanases', 'MAM domain profile.', 'CCP_2', 'Somatomedin B domain (SMB) signature.']",
#  'CPIJ004893-PA': "['BAX INHIBITOR-RELATED', 'BAX INHIBITOR 1', 'Inhibitor of apoptosis-promoting Bax1']",
#  'CPIJ016765-PA': "['RHO GTPASE-ACTIVATING PROTEIN 68F', 'CRAL/TRIO domain', 'Phosphatidylinositol Transfer Protein Sec14p', 'GANGLIOSIDE-INDUCED DIFFERENTIATION-ASSOCIATED PROTEIN 2', 'SEC14', 'CRAL-TRIO lipid binding domain profile.', 'sec14_4', 'Divergent CRAL/TRIO domain']",
#  'CPIJ001547-PA': "['DEAD-box RNA helicase Q motif profile.', 'Superfamilies 1 and 2 helicase C-terminal domain profile.', 'DEAD-box subfamily ATP-dependent helicases signature.', 'Superfamilies 1 and 2 helicase ATP-binding type-1 domain profile.', 'ultradead3', 'Helicase conserved C-terminal domain', 'DEAD/DEAH box helicase', 'EUKARYOTIC INITIATION FACTOR 4A-II', 'helicmild6', '-', 'SF2_C_DEAD', 'DEADc_EIF4AII_EIF4AI_DDX2', 'P-loop containing nucleoside triphosphate hydrolases', 'RNA HELICASE']",
#  'CPIJ006734-PA': "['rpol4neu2', '-', 'DNA-DIRECTED RNA POLYMERASE II SUBUNIT RPB4', 'DNA-DIRECTED RNA POLYMERASE II', 'HRDC-like', 'RNA polymerase Rpb4']",
#  'CPIJ016780-PA': "['Mitochondrial carrier protein', 'Solute carrier (Solcar) repeat profile.', 'Mitochondrial carrier domain', 'MITOCHONDRIAL 2-OXOGLUTARATE/MALATE CARRIER PROTEIN', 'Mitochondrial carrier', 'MITOCHONDRIAL DICARBOXYLATE CARRIER-RELATED']",
#  'CPIJ018033-PA': "['-', 'Trypsin', 'FI18411P1-RELATED', 'trypsin_2', 'Serine proteases, trypsin family, serine active site.', 'Tryp_SPc', 'Trypsin-like serine proteases', 'Chymotrypsin serine protease family (S1) signature', 'Serine proteases, trypsin domain profile.']",
#  'CPIJ000219-PA': "['consensus disorder prediction']",
#  'CPIJ010112-PA': "['Ribosomal_L18_L5e', 'Translational machinery components', 'Ribosomal large subunit proteins 60S L5, and 50S L18', 'Ribosomal L18 C-terminal region', '-', 'RIBOSOMAL PROTEIN L5-RELATED', 'Ribosomal protein L5 signature']",
#  'CPIJ011991-PA': "['consensus disorder prediction']",
#  'CPIJ001755-PA': "['Cytochrome P450', 'E-class P450 group I signature', 'Cytochrome p450', 'CYTOCHROME P450 FAMILY 4', 'CYTOCHROME P450 4P1-RELATED', 'Cytochrome P450 cysteine heme-iron ligand signature.', 'P450 superfamily signature']",
#  'CPIJ002305-PA': "['ADP-RIBOSYLATION FACTOR GTPASE ACTIVATING PROTEIN 3, ISOFORM H', 'ArfGap_ArfGap1_like', 'ArfGap/RecO-like zinc finger', 'ADP-RIBOSYLATION FACTOR GTPASE ACTIVATING PROTEIN 3, ISOFORM H-RELATED', 'Putative GTPase activating protein for Arf', 'HIV Rev interacting protein signature', 'arf_gap_3', '-', 'ARF GTPase-activating proteins domain profile.']",
#  'CPIJ007075-PA': "['Aminoacyl-transfer RNA synthetases class-I signature.', 'Nucleotidylyl transferase', 'Trypsin-like serine proteases', '-', 'Anticodon-binding domain of tRNA ligase', 'LEUCINE--TRNA LIGASE, CYTOPLASMIC', 'Serine proteases, trypsin domain profile.', 'Trypsin', 'ValRS/IleRS/LeuRS editing domain', 'Anticodon-binding domain of a subclass of class I aminoacyl-tRNA synthetases', 'trypsin_2', 'tRNA synthetases class I (I, L, M and V)', 'Serine proteases, trypsin family, histidine active site.', 'LEUCYL-TRNA SYNTHETASE', 'Anticodon_Ia_Leu_AEc']",
#  'CPIJ001599-PA': "['Coil', 'consensus disorder prediction', 'Sec7 domain', '-', 'GUANYL-NUCLEOTIDE EXCHANGE FACTOR', 'CYTOHESIN-1']",
#  'CPIJ004814-PA': "['Proteasome maturation factor UMP1', 'PROTEASOME MATURATION PROTEIN  UMP1', 'PROTEASOME MATURATION PROTEIN']",
#  'CPIJ002865-PA': "['-', 'cAMP/cGMP binding motif profile.', 'consensus disorder prediction', 'VOLTAGE AND LIGAND GATED POTASSIUM CHANNEL', 'CAP_ED', 'EAG/ELK/ERG potassium channel family signature', 'cAMP-binding domain-like', 'Coil', 'Jelly Rolls', 'cnmp_10', 'Ion transport protein', 'EAG potassium channel signature', 'Voltage-gated potassium channels', 'POTASSIUM VOLTAGE-GATED CHANNEL PROTEIN EAG', 'Cyclic nucleotide-binding domain']",
#  'CPIJ002646-PA': "['consensus disorder prediction', 'Coil']",
#  'CPIJ001894-PA': '[\'Prolyl oligopeptidase family\', \'-\', \'alpha/beta-Hydrolases\', \'Prolyl endopeptidase family serine active site.\', \'Prolyl oligopeptidase serine protease (S9A) signature\', \'Prolyl oligopeptidase, N-terminal beta-propeller domain\', \'PROLYL ENDOPEPTIDASE\', \'Prolyl oligopeptidase\', "Peptidase/esterase \'gauge\' domain"]',
#  'CPIJ002940-PA': "['Serine proteases, trypsin family, histidine active site.', 'Tryp_SPc', '-', 'Trypsin-like serine proteases', 'Serine proteases, trypsin family, serine active site.', 'trypsin_2', 'Trypsin', 'Chymotrypsin serine protease family (S1) signature', 'GH13245P2-RELATED', 'Serine proteases, trypsin domain profile.', 'POLYSERASE-RELATED']",
#  'CPIJ007494-PA': "['-', 'NEUROLIGIN', 'NEUROLIGIN 3, ISOFORM B', 'alpha/beta-Hydrolases', 'Carboxylesterase family']",
#  'CPIJ019375-PA': "['PTB domain (IRS-1 type)', 'consensus disorder prediction', '-', 'PH domain-like', 'Coil', 'IRS-type PTB domain profile.', 'IRS_2', 'PROTEIN DOK-7']",
#  'CPIJ015645-PA': "['Protein kinase domain', 'Protein kinase-like (PK-like)', 'Serine/Threonine protein kinases active-site signature.', 'Transferase(Phosphotransferase) domain 1', 'SERINE/THREONINE-PROTEIN KINASE', 'serkin_6', 'consensus disorder prediction', 'Protein kinase domain profile.', 'Phosphorylase Kinase; domain 1', 'STKc_MAPKAPK', 'Protein kinases ATP-binding region signature.', 'MAP kinase activated protein kinase 2', 'MAP KINASE-ACTIVATED PROTEIN KINASE 2']",
#  'CPIJ016321-PA': "['FAD binding domain', '-', 'ALKYLDIHYDROXYACETONEPHOSPHATE SYNTHASE, PEROXISOMAL', 'FAD-binding/transporter-associated domain-like', 'FAD-linked oxidases, C-terminal domain', 'PCMH-type FAD-binding domain profile.', 'FAD linked oxidases, C-terminal domain']",
#  'CPIJ011413-PA': "['Thioredoxin domain profile.', 'AhpC/TSA family', 'Thioredoxin-like', 'PRX_Typ2cys', 'THIOREDOXIN PEROXIDASE', 'PEROXIREDOXIN-4', 'C-terminal domain of 1-Cys peroxiredoxin', 'Glutaredoxin']",
#  'CPIJ010866-PA': "['consensus disorder prediction', 'Coil', 'Zinc finger C2H2 type domain profile.', 'beta-beta-alpha zinc fingers', 'Classic Zinc Finger', 'Zinc finger C2H2 type domain signature.', 'Glucocorticoid receptor-like (DNA-binding domain)', 'zf_AD_2', 'c2h2final6', 'Zinc-finger associated domain (zf-AD)']",
#  'CPIJ013638-PA': "['LamG_3', 'NEUREXIN 1, ISOFORM F', 'EGF_CA', 'consensus disorder prediction', 'Laminin G domain profile.', 'LamG', '-', 'PIKACHURIN-LIKE PROTEIN', 'Laminin', 'Concanavalin A-like lectins/glucanases', 'Laminin G domain', 'EGF-like domain profile.']",
#  'CPIJ003194-PA': "['PROTEIN TWEETY', 'Coil', 'TWEETY-RELATED', 'consensus disorder prediction', 'Tweety']",
#  'CPIJ003683-PA': "['Family A G protein-coupled receptor-like', '7 transmembrane receptor (rhodopsin family)', 'consensus disorder prediction', 'G-protein coupled receptors family 1 profile.', '5-HYDROXYTRYPTAMINE RECEPTOR', '5-HYDROXYTRYPTAMINE RECEPTOR 2A-RELATED', '-', 'Rhodopsin-like GPCR superfamily signature']",
#  'CPIJ016893-PA': "['consensus disorder prediction']",
#  'CPIJ000310-PA': "['-', 'HEPARAN SULFATE 2-O-SULFOTRANSFERASE', 'URONYL 2-SULFOTRANSFERASE', 'P-loop containing nucleoside triphosphate hydrolases', 'Sulfotransferase family']",
#  'CPIJ001344-PA': "['Protein of unknown function (DUF3128)', 'UPF0545 PROTEIN C22ORF39']",
#  'CPIJ015971-PA': '[\'PCI domain profile.\', \'PCI domain\', \'motif in proteasome subunits, Int-6, Nip-1 and TRIP-15\', \'26S proteasome subunit RPN6 C-terminal helix domain\', \'PINT_4\', \'-\', \'26S proteasome regulatory subunit RPN6 N-terminal domain\', \'26S PROTEASOME NON-ATPASE REGULATORY SUBUNIT 11A\', \'26S PROTEASOME NON-ATPASE REGULATORY SUBUNIT 11/COP9 SIGNALOSOME COMPLEX SUBUNIT 2\', \'"Winged helix" DNA-binding domain\']',
#  'CPIJ013087-PA': "['WOLFRAMIN', 'consensus disorder prediction', '-', 'Wolframin family signature']",
#  'CPIJ004095-PA': "['Serine proteases, trypsin family, serine active site.', '-', 'trypsin_2', 'Serine proteases, trypsin domain profile.', 'TRYPTASE-RELATED', 'Tryp_SPc', 'LD47230P-RELATED', 'Trypsin', 'Trypsin-like serine proteases']",
#  'CPIJ020035-PA': "['FACTOR VIII-ASSOCIATED GENE 1']",
#  'CPIJ007733-PA': "['PQ-LOOP REPEAT-CONTAINING PROTEIN 1-LIKE PROTEIN', 'PQ loop repeat']",
#  'CPIJ013670-PA': "['ArgE / dapE / ACY1 / CPG2 / yscS family signature 2.', '-', 'Ac-peptdase-euk: N-acyl-L-amino-acid amidohydrolase', 'AMINOACYLASE-1', 'Bacterial exopeptidase dimerisation domain', 'ACY-1', 'Zn-dependent exopeptidases', 'Peptidase family M20/M25/M40', 'Zn peptidases', 'Peptidase dimerisation domain']",
#  'CPIJ013552-PA': "['DYNAMIN', 'Dynamin-type guanine nucleotide-binding (G) domain profile.', 'DYNAMIN-1', 'consensus disorder prediction', 'Dynamin signature', 'dynamin_3', 'DLP_1', 'Dynamin family', 'Dynamin central region', '-', 'P-loop containing nucleoside triphosphate hydrolases']",
#  'CPIJ016668-PA': "['consensus disorder prediction', 'CYSTEINE AND GLYCINE-RICH PROTEIN 2 BINDING PROTEIN', 'HOMEOBOX PROTEIN 13-RELATED']",
#  'CPIJ014590-PA': "['UNCHARACTERIZED', '-', 'PQQ-like domain', 'Quinoprotein alcohol dehydrogenase-like', 'ER membrane protein complex subunit 1, C-terminal']",
#  'CPIJ011320-PA': "['Ufc1', 'UBIQUITIN-FOLD MODIFIER-CONJUGATING ENZYME 1', 'Ubiquitin-fold modifier-conjugating enzyme 1', 'Ubiquitin Conjugating Enzyme', 'UBC-like']",
#  'CPIJ006391-PA': "['Plexin repeat', 'RasGAP_plexin_A', 'PLEXIN', 'Immunoglobulins', '-', 'Sema domain profile.', 'GTPase activation domain, GAP', 'sema', 'E set domains', 'TIG domain', 'Sema domain', 'PLEXIN A, ISOFORM A', 'Coil', 'IPT_plexin_repeat1', 'iptmega2', 'psinew7', 'Sema_plexin_like', 'TIG domain found in plexin', 'Plexin cytoplasmic RasGAP domain', 'IPT/TIG domain']",
# ...
#  'CPIJ016656-PA': "['NAD(P)-binding Rossmann-fold domains', 'short chain dehydrogenase', 'Glucose/ribitol dehydrogenase family signature', '-', 'PKSB']",
#  'CPIJ003341-PA': "['NOVEL PROTEIN SIMILAR TO VERTEBRATE ADP-RIBOSYLATION FACTOR 4 (ARF4) (ZGC:77650)', '-', 'Arf1_5_like', 'ADP RIBOSYLATION FACTOR-RELATED', 'arf_sub_2', 'ADP-ribosylation factor family', 'sar_sub_1', 'small GTPase Arf family profile.', 'GTP-binding SAR1 protein signature', 'P-loop containing nucleoside triphosphate hydrolases', 'rab_sub_5', 'small_GTP: small GTP-binding protein domain']",
#  'CPIJ009592-PA': "['-', 'AT20289P-RELATED', 'Trypsin-like serine proteases', 'Serine proteases, trypsin family, histidine active site.', 'Serine proteases, trypsin family, serine active site.', 'Serine proteases, trypsin domain profile.', 'POLYSERASE-RELATED', 'Trypsin', 'Tryp_SPc', 'trypsin_2', 'Chymotrypsin serine protease family (S1) signature']",
#  'CPIJ017476-PA': "['Coil', 'MAJOR FACILITATOR SUPERFAMILY DOMAIN-CONTAINING PROTEIN 8', 'MFS general substrate transporter', 'MFS general substrate transporter like domains', 'INNER MEMBRANE TRANSPORT PROTEIN YAJR']",
#  'CPIJ000738-PA': "['consensus disorder prediction', 'Zinc finger C2H2 type domain signature.', 'CHORION TRANSCRIPTION FACTOR CF2-RELATED', 'Zinc finger C2H2 type domain profile.', 'c2h2final6', 'zf_AD_2', 'Glucocorticoid receptor-like (DNA-binding domain)', 'ZINC FINGER PROTEIN', 'beta-beta-alpha zinc fingers', 'Zinc finger, C2H2 type', 'Classic Zinc Finger', 'Coil']",
#  'CPIJ001996-PA': "['consensus disorder prediction', 'AGAP013079-PA']",
#  'CPIJ019180-PA': "['consensus disorder prediction', 'Ninjurin', 'NINJURIN-RELATED', 'NINJURIN A ALPHA']",
#  'CPIJ004379-PA': "['short chain dehydrogenase', 'Short-chain dehydrogenase/reductase (SDR) superfamily signature', 'Short-chain dehydrogenases/reductases family signature.', 'Glucose/ribitol dehydrogenase family signature', 'MIP25013P-RELATED', 'NAD(P)-binding Rossmann-fold domains', '17beta-HSD1_like_SDR_c', '-', '11-beta-HSD1', 'RH59310P']",
#  'CPIJ005534-PA': "['-', 'PKSB', 'FI23927P1-RELATED', 'short chain dehydrogenase', 'Glucose/ribitol dehydrogenase family signature', 'NAD(P)-binding Rossmann-fold domains', 'Short-chain dehydrogenase/reductase (SDR) superfamily signature']",
#  'CPIJ018132-PA': "['Low-density lipoprotein receptor domain class A', 'LDL-receptor class A (LDLRA) domain signature.', 'LDL receptor-like module', 'consensus disorder prediction', 'LDL-receptor class A (LDLRA) domain profile.', 'LDLa_2', 'AGAP006059-PA', 'LDLa', '-', 'CUBILIN']",
#  'CPIJ004635-PA': "['UNCHARACTERIZED', '-', 'AGAP011368-PA', 'Insect pheromone/odorant-binding proteins', 'Coil']",
#  'CPIJ005608-PA': "['-', 'FLYWCH zinc finger domain', 'zf_AD_2', 'consensus disorder prediction', 'BCDNA.LD26519-RELATED', 'Zinc-finger associated domain (zf-AD)', 'Glucocorticoid receptor-like (DNA-binding domain)']",
#  'CPIJ019232-PA': "['AcCoA-C-Actrans: acetyl-CoA C-acyltransferase', 'ACETYL-COA ACETYLTRANSFERASE, MITOCHONDRIAL', 'Thiolases acyl-enzyme intermediate signature.', '-', 'Glutaredoxin', 'Thioredoxin-like', 'Thiolases signature 2.', 'Thiolase, N-terminal domain', 'Thiolase-like', 'ACETYL-COA C-ACYLTRANSFERASE', 'thiolase', 'Thiolase, C-terminal domain', 'Glutaredoxin-like domain (DUF836)']",
#  'CPIJ002934-PA': "['Zinc finger C2H2 type domain signature.', 'Zinc finger C2H2 type domain profile.', 'consensus disorder prediction', 'beta-beta-alpha zinc fingers', 'PROTEIN KRUEPPEL', 'ZINC FINGER PROTEIN', 'c2h2final6', 'Classic Zinc Finger']",
#  'CPIJ000341-PA': "['Coil', 'consensus disorder prediction']",
#  'CPIJ002061-PA': "['-', 'RNA POLYMERASE II SUBUNIT 5-MEDIATING PROTEIN  NNX3', 'Prefoldin subunit', 'consensus disorder prediction', 'Coil', 'UNCONVENTIONAL PREFOLDIN RPB5 INTERACTOR 1', 'Prefoldin']",
#  'CPIJ011103-PA': '[\'M1_APN-Q_like\', \'-\', \'tricorn interacting facor f3 domain\', \'Peptidase M1 N-terminal domain\', \'PROTEASE M1 ZINC METALLOPROTEASE\', \'ERAP1-like C-terminal domain\', \'Membrane alanyl dipeptidase (M1) family signature\', \'Leukotriene A4 hydrolase N-terminal domain\', \'Peptidase family M1 domain\', \'Metalloproteases ("zincins"), catalytic domain\', \'AMINOPEPTIDASE-RELATED\']',
#  'CPIJ016055-PA': "['Zinc finger, C2H2 type', 'Zinc finger C2H2 type domain profile.', 'ZINC FINGER PROTEIN 142', 'c2h2final6', 'beta-beta-alpha zinc fingers', 'Classic Zinc Finger', 'zf_AD_2', 'Glucocorticoid receptor-like (DNA-binding domain)', 'AZ2-RELATED', 'consensus disorder prediction', 'Zinc-finger associated domain (zf-AD)']",
#  'CPIJ009408-PA': "['N-ACETYLGALACTOSAMINYLTRANSFERASE', 'Ricin B-like lectins', '-', 'RICIN', 'Glycosyl transferase family 2', 'Lectin domain of ricin B chain profile.', 'Nucleotide-diphospho-sugar transferases', 'Ricin-type beta-trefoil lectin domain', 'POLYPEPTIDE N-ACETYLGALACTOSAMINYLTRANSFERASE 3', 'pp-GalNAc-T', 'Spore Coat Polysaccharide Biosynthesis Protein SpsA; Chain A']",
#  'CPIJ011564-PA': "['7tm Chemosensory receptor', 'INVERTEBRATE GUSTATORY RECEPTOR', 'GUSTATORY RECEPTOR 58A-RELATED']",
#  'CPIJ014675-PA': "['consensus disorder prediction', 'Drf_GBD_2', 'Diaphanous FH3 Domain', 'MULTIPLE WING HAIRS, ISOFORM C', 'Coil', 'ARM repeat', '-', 'FORMIN-LIKE PROTEIN', 'Rho GTPase-binding/formin homology 3 (GBD/FH3) domain profile.', 'Drf_FH3_2']",
#  'CPIJ011993-PA': "['Sodium / potassium ATPase beta chain', 'Na', 'SODIUM/POTASSIUM-DEPENDENT ATPASE BETA SUBUNIT', 'SODIUM/POTASSIUM-TRANSPORTING ATPASE SUBUNIT BETA-2']",
#  'CPIJ006032-PA': "['Second domain of FERM', '-', 'FERM domain profile.', 'FERM N-terminal domain', '4.1 G PROTEIN', 'consensus disorder prediction', 'FERM C-terminal PH-like domain', 'FERM_C_3', 'B41_5', 'Band 4.1 protein family signature', 'Ubiquitin-like', 'ERM family signature', 'FERM_B-lobe', 'FERM domain signature 2.', 'FERM central domain', 'FERM adjacent (FA)', 'PROTEIN 4.1 HOMOLOG', 'FERM_F0_F1', 'PH domain-like', 'FERM_C_4_1_family', '4.1 protein C-terminal domain (CTD)', 'FA_2']",
#  'CPIJ004756-PA': "['UNCHARACTERIZED', 'Protein of unknown function (DUF1091)', 'CHEMOSENSORY PROTEIN A 29A-RELATED']",
#  'CPIJ007999-PA': "['C-type lectin domain signature.', 'C-type lectin domain profile.', 'METALLOENDOPEPTIDASE', 'LITHOSTATHINE', 'Lectin C-type domain', 'CLECT', '-', 'CLECT_2', 'C-type lectin-like']",
#  'CPIJ013306-PA': "['consensus disorder prediction', 'PX_2', 'PX domain', 'PX domain profile.', 'SORTING NEXIN 20, 21']",
#  'CPIJ014835-PA': "['-']",
#  'CPIJ004419-PA': "['-', 'consensus disorder prediction', 'Nucleosome assembly protein (NAP)', 'NAP-like', 'TESTIS-SPECIFIC Y-ENCODED PROTEIN', 'AT14585P-RELATED']",
#  'CPIJ007840-PA': "['consensus disorder prediction', 'Cyclin-like']",
#  'CPIJ011852-PA': "['LYSOSOMAL ACID LIPASE-RELATED', 'Partial alpha/beta-hydrolase lipase region', 'Steryl_ester_lip', 'alpha/beta hydrolase fold', '-', 'alpha/beta-Hydrolases', 'LIPASE-RELATED']",
#  'CPIJ002757-PA': "['CELLULAR TUMOR ANTIGEN P53', 'consensus disorder prediction', 'P53 DNA-binding domain', 'p53-like transcription factors', 'P53', '-', 'P53 PROTEIN LONG FORM VARIANT 1']",
#  'CPIJ012518-PA': '[\'HOX_1\', "\'Homeobox\' domain signature.", \'Homeodomain-like\', \'consensus disorder prediction\', \'-\', \'Homeodomain\', \'homeodomain\', "\'Homeobox\' domain profile.", \'BRAIN-SPECIFIC HOMEOBOX PROTEIN-RELATED\', \'HOMEOBOX PROTEIN\', \'Lambda-repressor HTH signature\', \'Homeobox signature\']',
#  'CPIJ016259-PA': "['Cellular retinaldehyde-binding protein signature', 'CRAL-TRIO lipid binding domain profile.', 'CRAL/TRIO domain', 'CRAL/TRIO N-terminal domain', '-', 'ALPHA-TOCOPHEROL TRANSFER PROTEIN-RELATED', 'LD40136P', 'SEC14', 'Phosphatidylinositol Transfer Protein Sec14p', 'CRAL_TRIO_N_2', 'Coil']",
#  'CPIJ012213-PA': "['Coil', 'consensus disorder prediction']",
#  'CPIJ005877-PA': "['MITOGUARDIN', 'consensus disorder prediction', 'Mitoguardin']",
#  'CPIJ008055-PA': "['TBC1 DOMAIN FAMILY MEMBER GTPASE-ACTIVATING PROTEIN', 'Coil', 'TBC/rab GAP domain profile.', 'Ypt/Rab-GAP domain of gyp1p', 'Rab-GTPase-TBC domain', '-', 'putative rabgap domain of human tbc1 domain family member 14 like domains', 'tbc_4', 'TBC1 DOMAIN FAMILY MEMBER 16']",
#  'CPIJ002548-PA': "['Coil', 'Bivalent Mical/EHBP Rab binding domain', 'DUF3585_4', 'consensus disorder prediction', 'CALPONIN HOMOLOGY DOMAIN-CONTAINING PROTEIN DDB_G0272472-RELATED', 'bMERB domain profile.', 'MICAL-LIKE 1A-RELATED']",
#  'CPIJ010398-PA': "['-', 'Ribonuclease T2 family histidine active site 2.', 'Ribonuclease Rh-like', 'RNase_T2_euk', 'RIBONUCLEASE T2', 'Ribonuclease T2 family']",
#  'CPIJ013665-PA': "['FI04408P', 'RNA-binding domain, RBD', '-', 'rrm1_1', 'RRM2_TIA1_like', 'RRM3_TIA1_like', 'EUKARYOTIC TRANSLATION INITIATION FACTOR 3 SUBUNIT G', 'Eukaryotic RNA Recognition Motif (RRM) profile.', 'RNA recognition motif. (a.k.a. RRM, RBD, or RNP domain)', 'RRM1_TIA1_like', 'rrm2_1']",
#  'CPIJ012632-PA': '[\'Cysteine Rich Protein\', \'LIM domain\', \'LIM2_Isl\', \'LIM zinc-binding domain signature.\', "\'Homeobox\' domain signature.", \'-\', \'INSULIN GENE ENHANCER PROTEIN\', \'Homeodomain\', "\'Homeobox\' domain profile.", \'Homeodomain-like\', \'lim_4\', \'homeodomain\', \'HOX_1\', \'LIM domain profile.\', \'TAILUP, ISOFORM A\', \'consensus disorder prediction\', \'Glucocorticoid receptor-like (DNA-binding domain)\', \'LIM1_Isl\']',
#  'CPIJ001854-PA': "['Ankyrin repeat', 'Ankyrin repeats (3 copies)', 'Ankyrin repeat profile.', 'Ankyrin repeat region circular profile.', 'ANK_2a', 'SOCS_box_2', 'ANKYRIN REPEAT-CONTAINING PROTEIN DDB_G0279043', '-', 'Ankyrin repeat signature']",
#  'CPIJ005400-PA': "['ODORANT RECEPTOR 19A-RELATED', '7tm Odorant receptor', 'ODORANT RECEPTOR']",
#  'CPIJ016127-PA': "['TMEM164 family', 'UNCHARACTERIZED', 'TRANSMEMBRANE PROTEIN 164']",
#  'CPIJ003744-PA': "['Glutamine synthetase, beta-Grasp domain', 'Glutamine synthetase signature 1.', 'Glutamine synthetase, N-terminal domain', 'Glutamine synthetase, catalytic domain', 'Glutamine synthetase putative ATP-binding region signature.', '-', 'Glutamine synthetase', 'GLUTAMINE SYNTHETASE 2 CYTOPLASMIC', 'GLUTAMINE SYNTHETASE', 'Glutamine synthetase/guanido kinase', 'Gln_synt_C_2']",
#  'CPIJ007281-PA': "['consensus disorder prediction', 'T-CELL IMMUNOGLOBULIN AND MUCIN DOMAIN CONTAINING  TIM', 'MEDIATOR OF RNA POLYMERASE II TRANSCRIPTION SUBUNIT 7', 'Mediator hinge subcomplex-like', 'MED7 protein']",
#  'CPIJ009106-PA': '[\'M2_ACE\', \'Angiotensin-converting enzyme\', \'Metalloproteases ("zincins"), catalytic domain\', \'Peptidyl-dipeptidase A (M2) metalloprotease family signature\', \'ANGIOTENSIN-CONVERTING ENZYME\']',
#  'CPIJ014284-PA': "['AGAP013526-PA', 'UNCHARACTERIZED']",
#  'CPIJ014467-PA': "['-', 'P-loop containing nucleoside triphosphate hydrolases', 'Sulfotransferase family', 'WSCD FAMILY MEMBER CG9164']",
#  'CPIJ001002-PA': '[\'Homeodomain-like\', \'Homeobox signature\', \'consensus disorder prediction\', \'Homeodomain\', \'homeodomain\', \'-\', \'HOX_1\', "\'Homeobox\' domain profile.", \'ZEN\', "\'Homeobox\' domain signature.", \'HOMEO BOX HB9 LIKE A-RELATED\']',
#  'CPIJ015981-PA': "['alpha/beta hydrolase fold', 'alpha/beta-Hydrolases', 'consensus disorder prediction', '-', 'Hormone-sensitive lipase (HSL) N-terminus', 'TRIACYLGLYCEROL LIPASE', 'Coil']",
#  'CPIJ016894-PA': "['ZINC FINGER SWIM DOMAIN-CONTAINING PROTEIN 7', 'Zinc finger SWIM-type profile.']",
#  'CPIJ020324-PA': "['consensus disorder prediction']",
#  'CPIJ017733-PA': "['SI:DKEY-187J14.7-RELATED', 'SecA DEAD-like domain', 'Coil', 'P-loop containing nucleoside triphosphate hydrolases', 'SecA family profile.', 'SECA INNER MEMBRANE COMPONENT OF SEC PROTEIN SECRETION SYSTEM', '-']",
#  'CPIJ004770-PA': "['tRNA synthetase B5 domain', 'Putative DNA-binding domain', '-', 'B5_2', 'B5 domain profile.', 'PHENYLALANYL-TRNA SYNTHETASE BETA CHAIN AND LEUCINE-RICH REPEAT-CONTAINING PROTEIN 47', 'PHENYLALANINE--TRNA LIGASE BETA SUBUNIT']",
#  'CPIJ005160-PA': "['SERINE PROTEASE FAMILY S1C HTRA-RELATED', 'Trypsin-like serine proteases', '-', 'HtrA/DegQ protease family signature', 'Trypsin-like peptidase domain']",
#  'CPIJ002057-PA': "['LRR_typ_2', 'Leucine-rich repeat profile.', 'Leucine-rich repeat signature', 'Ribonuclease Inhibitor', 'LEUCINE-RICH REPEAT-CONTAINING PROTEIN 59', 'LRR_sd22_2', 'L domain-like', 'Leucine rich repeat', 'LEUCINE-RICH REPEAT-CONTAINING']",
#  'CPIJ011406-PA': "['consensus disorder prediction']",
#  'CPIJ015698-PA': "['consensus disorder prediction']",
#  'CPIJ007346-PA': "['TPR-like', 'Coil', 'TPR repeat profile.', 'Tetratricopeptide repeat', 'UNCHARACTERIZED', 'TPR repeat region circular profile.', 'tpr_5', '-']",
#  'CPIJ005071-PA': "['AUTOPHAGY PROTEIN 16-LIKE', 'AUTOPHAGY-RELATED PROTEIN 16-1', 'Trp-Asp (WD) repeats signature.', '-', 'Trp-Asp (WD) repeats circular profile.', 'Coil', 'Trp-Asp (WD) repeats profile.', 'WD40_4', 'Autophagy protein 16 (ATG16)', 'WD domain, G-beta repeat', 'WD40 repeat-like']",
#  'CPIJ010111-PA': "['Coil', 'CCR4-NOT TRANSCRIPTION COMPLEX, SUBUNIT 3B', 'Not1 N-terminal domain, CCR4-Not complex component', 'consensus disorder prediction', 'NOT_su_3_5', '-', 'CCR4 NOT-RELATED']",
#  'CPIJ002800-PA': "['LARVAL/PUPAL CUTICLE PROTEIN H1C-LIKE PROTEIN-RELATED', 'Pupal cuticle protein C1']",
#  'CPIJ001348-PA': "['F-BOX DOMAIN CONTAINING PROTEIN, EXPRESSED', 'F-box-like', 'fbox_2', 'F-box domain', 'LRR_CC_2', 'F-box domain profile.', '-', 'Ribonuclease Inhibitor', 'RNI-like']",
#  'CPIJ011675-PA': "['Elongation factor Tu GTP binding domain', 'P-loop containing nucleoside triphosphate hydrolases', '116 KDA U5 SMALL NUCLEAR RIBONUCLEOPROTEIN COMPONENT', 'Translation proteins', 'Translation factors', 'TRANSLATION ELONGATION FACTOR-RELATED', 'consensus disorder prediction', '-']",
#  'CPIJ000108-PA': "['GNS1/SUR4 family', 'ELONGATION OF VERY LONG CHAIN FATTY ACIDS PROTEIN', 'FATTY ACID ACYL TRANSFERASE-RELATED']",
#  'CPIJ012094-PA': "['VOLTAGE-GATED POTASSIUM CHANNEL', 'POTASSIUM VOLTAGE-GATED CHANNEL, KQT-LIKE SUBFAMILY, MEMBER 1-RELATED', 'consensus disorder prediction', 'KCNQ1 voltage-gated potassium channel signature', 'KCNQ voltage-gated potassium channel']",
#  'CPIJ019219-PA': "['consensus disorder prediction', 'WASP INTERACTING PROTEIN-RELATED', 'AGAP000559-PA', 'Coil']",
#  'CPIJ013267-PA': "['Low temperature viability protein', 'consensus disorder prediction', 'LOW-TEMPERATURE VIABILITY PROTEIN LTV1-RELATED', 'PROTEIN LTV1 HOMOLOG']",
#  'CPIJ014730-PA': "['CYTOCHROME P450 4V2', 'Cytochrome P450 cysteine heme-iron ligand signature.', 'Cytochrome p450', 'CYTOCHROME P450 FAMILY 4', 'Cytochrome P450', 'P450 superfamily signature', 'E-class P450 group I signature']",
#  'CPIJ006183-PA': "['beta-beta-alpha zinc fingers', 'Zinc finger, C2H2 type', 'Zinc finger C2H2 type domain signature.', 'zf_AD_2', 'Zinc finger C2H2 type domain profile.', 'Glucocorticoid receptor-like (DNA-binding domain)', 'Classic Zinc Finger', 'consensus disorder prediction', 'C2H2-type zinc finger', 'KRAB AND ZINC FINGER DOMAIN-CONTAINING', 'Zinc-finger associated domain (zf-AD)', 'c2h2final6']",
#  'CPIJ012045-PA': "['Gamma Fibrinogen', 'Fibrinogen C-terminal domain-like', 'FBG_2', '-', 'Fibrinogen beta and gamma chains, C-terminal globular domain', 'Fibrinogen C-terminal domain profile.', 'FIBRINOGEN/TENASCIN/ANGIOPOEITIN']",
#  'CPIJ014021-PA': "['consensus disorder prediction', 'CRAMPED PROTEIN', 'PROTEIN CRAMPED-LIKE']",
#  'CPIJ014629-PA': "['GENERAL TRANSCRIPTION FACTOR IIH SUBUNIT 5', 'TFB5-like', 'Tbf5_2', 'Transcription factor TFIIH complex subunit Tfb5', 'General transcription factor iih']",
#  'CPIJ017518-PA': "['consensus disorder prediction']",
#  ...}

# %%
OrthoGroup_GeneName_IntCQMiss, OrthoGroup_GeneName_IntCQ = createOrthoFunctionDict(OrthoGroup_GeneName_AG, Culex_quinquefasciatus_dict, "Culex_quinquefasciatus") 
OrthoGroup_GeneName_IntCQ = OrthoGroup_GeneName_IntCQ.rename(columns={"Function [CC]":"Function"})
OrthoGroup_GeneName_IntCQ
# Out:
#     Orthogroup                                      Aedes_aegypti  \
# 0    OG0000000                                                NaN
# 1    OG0000103  AAEL015526-PA, AAEL020698-PA, AAEL022625-PA, A...
# 2    OG0000187  AAEL010406-PB, AAEL020602-PA, AAEL020602-PB, A...
# 3    OG0000276                                                NaN
# 4    OG0000703                                                NaN
# ..         ...                                                ...
# 177  OG0011040                                                NaN
# 178  OG0011041                                                NaN
# 179  OG0011042                                                NaN
# 180  OG0011043                                                NaN
# 181  OG0011044                                                NaN
#
#     Anopheles_gambiae        Culex_quinquefasciatus  \
# 0                 NaN                 CPIJ003781-PA
# 1                 NaN                 CPIJ002300-PA
# 2                 NaN  CPIJ006662-PA, CPIJ019426-PA
# 3                 NaN  CPIJ008196-PA, CPIJ012862-PA
# 4                 NaN                 CPIJ005619-PA
# ..                ...                           ...
# 177               NaN  CPIJ018872-PA, CPIJ019252-PA
# 178               NaN                 CPIJ018953-PA
# 179               NaN                 CPIJ019301-PA
# 180               NaN                 CPIJ019409-PA
# 181               NaN                 CPIJ020189-PA
#
#                                Drosophila_melanogaster  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    FBpp0290327, FBpp0290328, FBpp0290329, FBpp029...
# ..                                                 ...
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                        FBpp0077931
# 181                                                NaN
#
#                                       Wyeomyia_smithii  \
# 0    maker-tig00000051|arrow-exonerate_est2genome-g...
# 1    maker-tig00001522|arrow-exonerate_est2genome-g...
# 2    maker-tig00002642|arrow-exonerate_est2genome-g...
# 3    maker-tig00001080|arrow-exonerate_est2genome-g...
# 4                                                  NaN
# ..                                                 ...
# 177                                                NaN
# 178  maker-tig00015778|arrow-exonerate_est2genome-g...
# 179  maker-tig00266848|arrow-exonerate_est2genome-g...
# 180                                                NaN
# 181  maker-tig00028367|arrow-exonerate_est2genome-g...
#
#                                               Function
# 0    [['consensus disorder prediction'], ['consensu...
# 1    [['consensus disorder prediction'], ['consensu...
# 2    [['IP13529P', 'ZINC FINGER, C2H2 TYPE DOMAINCO...
# 3                                       [['-'], ['-']]
# 4    [['consensus disorder prediction', '-', 'Colla...
# ..                                                 ...
# 177  [['consensus disorder prediction'], ['consensu...
# 178  [['Cytosolic carboxypeptidase N-terminal domai...
# 179  [['PROTEIN CBG13225', 'Helicase conserved C-te...
# 180  [['consensus disorder prediction'], ['consensu...
# 181  [['SNF-like', 'consensus disorder prediction',...
#
# [182 rows x 7 columns]

# %%
OrthoGroup_GeneName_PresentCQ = getMissingOrthogroup(OrthoGroup_GeneName_AG, OrthoGroup_GeneName_IntCQ)
OrthoGroup_GeneName_CQ = pd.merge(OrthoGroup_GeneName_AG, OrthoGroup_GeneName_PresentCQ, on= 'Orthogroup')
OrthoGroup_GeneName_CQ
# Out:
#     Orthogroup Aedes_aegypti Anopheles_gambiae  \
# 0    OG0000010           NaN               NaN
# 1    OG0000029           NaN               NaN
# 2    OG0000042           NaN               NaN
# 3    OG0000046           NaN               NaN
# 4    OG0000135           NaN               NaN
# ..         ...           ...               ...
# 451  OG0011105           NaN               NaN
# 452  OG0011106           NaN               NaN
# 453  OG0011107           NaN               NaN
# 454  OG0011108           NaN               NaN
# 455  OG0011109           NaN               NaN
#
#                           Culex_quinquefasciatus  \
# 0    CPIJ014066-PA, CPIJ017401-PA, CPIJ017423-PA
# 1                                  CPIJ003782-PA
# 2                                  CPIJ007606-PA
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 451                                          NaN
# 452                                          NaN
# 453                                          NaN
# 454                                          NaN
# 455                                          NaN
#
#                                Drosophila_melanogaster  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    FBpp0072260, FBpp0072261, FBpp0072283, FBpp008...
# 4    FBpp0083459, FBpp0083460, FBpp0083461, FBpp008...
# ..                                                 ...
# 451                                                NaN
# 452                                                NaN
# 453                                                NaN
# 454                                                NaN
# 455                                                NaN
#
#                                       Wyeomyia_smithii
# 0    maker-tig00001022|arrow-exonerate_est2genome-g...
# 1    maker-tig00000321|arrow-exonerate_est2genome-g...
# 2    maker-tig00000213|arrow-exonerate_est2genome-g...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 451  maker-tig00001261|arrow-exonerate_est2genome-g...
# 452  maker-tig00055620|arrow-exonerate_est2genome-g...
# 453  maker-tig00031758|arrow-exonerate_est2genome-g...
# 454  maker-tig00267066|arrow-exonerate_est2genome-g...
# 455  maker-tig00031038|arrow-exonerate_est2genome-g...
#
# [456 rows x 6 columns]

# %%
Drosophila_melanogaster = pd.read_excel("Drosophila_melanogaster.xlsx")
Drosophila_melanogaster = Drosophila_melanogaster.drop("Unnamed: 0", 1)
Drosophila_melanogaster
Drosophila_melanogaster_dict = {}

for i in range(len(Drosophila_melanogaster)):
    Drosophila_melanogaster_dict[Drosophila_melanogaster[0][i]] = Drosophila_melanogaster[1][i]

# %%
OrthoGroup_GeneName_IntDMMiss, OrthoGroup_GeneName_IntDM = createOrthoFunctionDict(OrthoGroup_GeneName_CQ, Drosophila_melanogaster_dict, "Drosophila_melanogaster") 
OrthoGroup_GeneName_IntDM = OrthoGroup_GeneName_IntDM.rename(columns={"Function [CC]":"Function"})
OrthoGroup_GeneName_IntDM
# Out:
#     Orthogroup Aedes_aegypti Anopheles_gambiae Culex_quinquefasciatus  \
# 0    OG0000046           NaN               NaN                    NaN
# 1    OG0000135           NaN               NaN                    NaN
# 2    OG0000306           NaN               NaN                    NaN
# 3    OG0000530           NaN               NaN                    NaN
# 4    OG0000992           NaN               NaN                    NaN
# ..         ...           ...               ...                    ...
# 197  OG0011090           NaN               NaN                    NaN
# 198  OG0011091           NaN               NaN                    NaN
# 199  OG0011092           NaN               NaN                    NaN
# 200  OG0011093           NaN               NaN                    NaN
# 201  OG0011094           NaN               NaN                    NaN
#
#                                Drosophila_melanogaster  \
# 0    FBpp0072260, FBpp0072261, FBpp0072283, FBpp008...
# 1    FBpp0083459, FBpp0083460, FBpp0083461, FBpp008...
# 2    FBpp0088376, FBpp0088377, FBpp0088378, FBpp008...
# 3    FBpp0311310, FBpp0311311, FBpp0311312, FBpp031...
# 4    FBpp0076909, FBpp0086025, FBpp0086462, FBpp008...
# ..                                                 ...
# 197                           FBpp0071385, FBpp0298822
# 198                                        FBpp0073718
# 199                           FBpp0074383, FBpp0074384
# 200                           FBpp0074461, FBpp0310190
# 201                           FBpp0099828, FBpp0309047
#
#                                       Wyeomyia_smithii  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 197                                                NaN
# 198  maker-tig00265258|arrow-exonerate_est2genome-g...
# 199                                                NaN
# 200                                                NaN
# 201                                                NaN
#
#                                               Function
# 0    [['Protein of unknown function (DUF1091)', 'dm...
# 1    [['Potassium Channel Kv1.1; Chain A', 'consens...
# 2    [['Potassium Channel Kv1.1; Chain A', 'Zinc fi...
# 3    [['Coil', 'consensus disorder prediction'], ['...
# 4    [['Periplasmic binding protein-like II', 'IONO...
# ..                                                 ...
# 197  [['Zinc finger, C2H2 type', '-', 'Zinc finger ...
# 198  [['consensus disorder prediction', '-', 'Super...
# 199  [['consensus disorder prediction', 'DPY-19-LIK...
# 200  [['IP12869P', 'MFS general substrate transport...
# 201  [['consensus disorder prediction', 'LisH', 'Co...
#
# [202 rows x 7 columns]

# %%
OrthoGroup_GeneName_PresentDM = getMissingOrthogroup(OrthoGroup_GeneName_CQ, OrthoGroup_GeneName_IntDM)
OrthoGroup_GeneName_DM = pd.merge(OrthoGroup_GeneName_CQ, OrthoGroup_GeneName_PresentDM, on= 'Orthogroup')
OrthoGroup_GeneName_DM
# Out:
#     Orthogroup Aedes_aegypti  \
# 0    OG0000010           NaN
# 1    OG0000029           NaN
# 2    OG0000042           NaN
# 3    OG0000345           NaN
# 4    OG0000613           NaN
# ..         ...           ...
# 249  OG0011105           NaN
# 250  OG0011106           NaN
# 251  OG0011107           NaN
# 252  OG0011108           NaN
# 253  OG0011109           NaN
#
#                                      Anopheles_gambiae  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    AGAP007263-PA, AGAP007269-PA, AGAP007270-PA, A...
# 4                                                  NaN
# ..                                                 ...
# 249                                                NaN
# 250                                                NaN
# 251                                                NaN
# 252                                                NaN
# 253                                                NaN
#
#                           Culex_quinquefasciatus Drosophila_melanogaster  \
# 0    CPIJ014066-PA, CPIJ017401-PA, CPIJ017423-PA                     NaN
# 1                                  CPIJ003782-PA                     NaN
# 2                                  CPIJ007606-PA                     NaN
# 3                                            NaN                     NaN
# 4                                  CPIJ018370-PA                     NaN
# ..                                           ...                     ...
# 249                                          NaN                     NaN
# 250                                          NaN                     NaN
# 251                                          NaN                     NaN
# 252                                          NaN                     NaN
# 253                                          NaN                     NaN
#
#                                       Wyeomyia_smithii
# 0    maker-tig00001022|arrow-exonerate_est2genome-g...
# 1    maker-tig00000321|arrow-exonerate_est2genome-g...
# 2    maker-tig00000213|arrow-exonerate_est2genome-g...
# 3                                                  NaN
# 4    maker-tig00002258|arrow-exonerate_est2genome-g...
# ..                                                 ...
# 249  maker-tig00001261|arrow-exonerate_est2genome-g...
# 250  maker-tig00055620|arrow-exonerate_est2genome-g...
# 251  maker-tig00031758|arrow-exonerate_est2genome-g...
# 252  maker-tig00267066|arrow-exonerate_est2genome-g...
# 253  maker-tig00031038|arrow-exonerate_est2genome-g...
#
# [254 rows x 6 columns]

# %%
Wyeomyia_samithii = pd.read_excel("Wyeomyia_samithii.xlsx")
Wyeomyia_samithii = Wyeomyia_samithii.drop("Unnamed: 0", 1)
Wyeomyia_samithii
Wyeomyia_samithii_dict = {}

for i in range(len(Wyeomyia_samithii)):
    Wyeomyia_samithii_dict[Wyeomyia_samithii[0][i]] = Wyeomyia_samithii[1][i]

# %%
OrthoGroup_GeneName_IntWSMiss, OrthoGroup_GeneName_IntWS = createOrthoFunctionDict(OrthoGroup_GeneName_DM, Wyeomyia_samithii_dict, "Wyeomyia_smithii") 
OrthoGroup_GeneName_IntWS = OrthoGroup_GeneName_IntWS.rename(columns={"Function [CC]":"Function"})
OrthoGroup_GeneName_IntWS
# Out:
#    Orthogroup                                      Aedes_aegypti  \
# 0   OG0000613                                                NaN
# 1   OG0001481  AAEL001820-PA, AAEL018004-PC, AAEL020509-PA, A...
# 2   OG0002085                                                NaN
# 3   OG0002570                                                NaN
# 4   OG0002648                                      AAEL009480-PA
# 5   OG0002706  AAEL020275-PA, AAEL020275-PD, AAEL020275-PE, A...
# 6   OG0007022                                                NaN
# 7   OG0007024                                                NaN
# 8   OG0007103                                      AAEL003803-PA
# 9   OG0009119                                      AAEL003171-PB
# 10  OG0009376                                      AAEL020317-PA
# 11  OG0009409                       AAEL024581-PA, AAEL026341-PA
# 12  OG0009715                                      AAEL017145-PA
# 13  OG0009762                       AAEL024468-PA, AAEL024791-PA
# 14  OG0009859                                                NaN
# 15  OG0009867                                                NaN
# 16  OG0009914                                                NaN
# 17  OG0010201                                      AAEL020342-PA
# 18  OG0010415                                      AAEL023892-PA
# 19  OG0010442                                      AAEL028073-PA
# 20  OG0010533                                                NaN
# 21  OG0010540                                                NaN
# 22  OG0010585                                                NaN
# 23  OG0010586                                                NaN
# 24  OG0010588                                                NaN
# 25  OG0010689                                      AAEL008911-PA
# 26  OG0010740                                      AAEL026597-PA
# 27  OG0011033                                                NaN
# 28  OG0011095                                                NaN
# 29  OG0011096                                                NaN
# 30  OG0011097                                                NaN
# 31  OG0011099                                                NaN
# 32  OG0011101                                                NaN
# 33  OG0011102                                                NaN
# 34  OG0011103                                                NaN
# 35  OG0011104                                                NaN
# 36  OG0011105                                                NaN
# 37  OG0011106                                                NaN
# 38  OG0011107                                                NaN
# 39  OG0011108                                                NaN
# 40  OG0011109                                                NaN
#
#                               Anopheles_gambiae  \
# 0                                           NaN
# 1   AGAP009018-PA, AGAP029872-PA, AGAP029873-PA
# 2                                           NaN
# 3   AGAP004681-PA, AGAP010484-PA, AGAP012904-PA
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                 AGAP000268-PA
# 9                                           NaN
# 10                                AGAP028599-PA
# 11                                          NaN
# 12                                AGAP001510-PA
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                AGAP006977-PA
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN
# 36                                          NaN
# 37                                          NaN
# 38                                          NaN
# 39                                          NaN
# 40                                          NaN
#
#                          Culex_quinquefasciatus Drosophila_melanogaster  \
# 0                                 CPIJ018370-PA                     NaN
# 1   CPIJ010936-PA, CPIJ010937-PA, CPIJ016292-PA                     NaN
# 2                                           NaN                     NaN
# 3                                           NaN                     NaN
# 4                                 CPIJ007148-PA                     NaN
# 5                                           NaN                     NaN
# 6                                           NaN                     NaN
# 7                                           NaN                     NaN
# 8                                 CPIJ016751-PA                     NaN
# 9                                           NaN                     NaN
# 10                                CPIJ039838-PA                     NaN
# 11                                CPIJ008218-PA                     NaN
# 12                                CPIJ011584-PA                     NaN
# 13                                CPIJ014402-PA                     NaN
# 14                 CPIJ007702-PA, CPIJ015746-PA                     NaN
# 15                                CPIJ016764-PA                     NaN
# 16                                          NaN                     NaN
# 17                                          NaN                     NaN
# 18                                          NaN                     NaN
# 19                                          NaN                     NaN
# 20                                CPIJ009487-PA                     NaN
# 21                                CPIJ010635-PA                     NaN
# 22                                          NaN                     NaN
# 23                                          NaN                     NaN
# 24                                          NaN                     NaN
# 25                                          NaN                     NaN
# 26                                          NaN                     NaN
# 27                                CPIJ016899-PA                     NaN
# 28                                          NaN                     NaN
# 29                                          NaN                     NaN
# 30                                          NaN                     NaN
# 31                                          NaN                     NaN
# 32                                          NaN                     NaN
# 33                                          NaN                     NaN
# 34                                          NaN                     NaN
# 35                                          NaN                     NaN
# 36                                          NaN                     NaN
# 37                                          NaN                     NaN
# 38                                          NaN                     NaN
# 39                                          NaN                     NaN
# 40                                          NaN                     NaN
#
#                                      Wyeomyia_smithii  \
# 0   maker-tig00002258|arrow-exonerate_est2genome-g...
# 1   maker-tig00008771|arrow-exonerate_est2genome-g...
# 2   maker-tig00000972|arrow-exonerate_est2genome-g...
# 3   maker-tig00005322|arrow-exonerate_est2genome-g...
# 4   maker-tig00033996|arrow-exonerate_est2genome-g...
# 5   maker-tig00003734|arrow-exonerate_est2genome-g...
# 6   maker-tig00004734|arrow-exonerate_est2genome-g...
# 7   maker-tig00001823|arrow-exonerate_est2genome-g...
# 8   maker-tig00055682|arrow-exonerate_est2genome-g...
# 9   maker-tig00041022|arrow-exonerate_est2genome-g...
# 10  maker-tig00070511|arrow-exonerate_est2genome-g...
# 11  maker-tig00007342|arrow-exonerate_est2genome-g...
# 12  maker-tig00103032|arrow-exonerate_est2genome-g...
# 13  maker-tig00013929|arrow-exonerate_est2genome-g...
# 14  maker-tig00000213|arrow-exonerate_est2genome-g...
# 15  maker-tig00044598|arrow-exonerate_est2genome-g...
# 16  maker-tig00004919|arrow-exonerate_est2genome-g...
# 17  maker-tig00267832|arrow-exonerate_est2genome-g...
# 18  maker-tig00019420|arrow-exonerate_est2genome-g...
# 19  maker-tig00010631|arrow-exonerate_est2genome-g...
# 20  maker-tig00050672|arrow-exonerate_est2genome-g...
# 21  maker-tig00036273|arrow-exonerate_est2genome-g...
# 22  maker-tig00001305|arrow-exonerate_est2genome-g...
# 23  maker-tig00023227|arrow-exonerate_est2genome-g...
# 24  maker-tig00045424|arrow-exonerate_est2genome-g...
# 25  maker-tig00105613|arrow-exonerate_est2genome-g...
# 26  maker-tig00027708|arrow-exonerate_est2genome-g...
# 27  maker-tig00265310|arrow-exonerate_est2genome-g...
# 28  maker-tig00006115|arrow-exonerate_est2genome-g...
# 29  maker-tig00036587|arrow-exonerate_est2genome-g...
# 30  maker-tig00094486|arrow-exonerate_est2genome-g...
# 31  maker-tig00025594|arrow-exonerate_est2genome-g...
# 32  maker-tig00046086|arrow-exonerate_est2genome-g...
# 33  maker-tig00031617|arrow-exonerate_est2genome-g...
# 34  maker-tig00008016|arrow-exonerate_est2genome-g...
# 35  maker-tig00006730|arrow-exonerate_est2genome-g...
# 36  maker-tig00001261|arrow-exonerate_est2genome-g...
# 37  maker-tig00055620|arrow-exonerate_est2genome-g...
# 38  maker-tig00031758|arrow-exonerate_est2genome-g...
# 39  maker-tig00267066|arrow-exonerate_est2genome-g...
# 40  maker-tig00031038|arrow-exonerate_est2genome-g...
#
#                                              Function
# 0      [['-', 'DNase I-like'], ['-', 'DNase I-like']]
# 1   [['Ganglioside M2 (gm2) activator'], ['Ganglio...
# 2   [['consensus disorder prediction'], ['consensu...
# 3   [['Coil', 'consensus disorder prediction'], ['...
# 4   [['MARVEL domain profile.', 'consensus disorde...
# 5                                [['Coil'], ['Coil']]
# 6   [['Reverse transcriptase (RNA-dependent DNA po...
# 7   [['THAP domain', 'Glucocorticoid receptor-like...
# 8   [['Prokaryotic membrane lipoprotein lipid atta...
# 9                                [['Coil'], ['Coil']]
# 10                               [['Coil'], ['Coil']]
# 11  [['consensus disorder prediction'], ['consensu...
# 12  [['Prokaryotic membrane lipoprotein lipid atta...
# 13  [['consensus disorder prediction'], ['consensu...
# 14  [['c2hcfinal6', 'consensus disorder prediction...
# 15  [['consensus disorder prediction'], ['consensu...
# 16  [['Methuselah N-terminus', '-', 'Methuselah ec...
# 17  [['consensus disorder prediction'], ['consensu...
# 18                               [['Coil'], ['Coil']]
# 19  [['-', 'FLYWCH zinc finger domain', 'PROTEIN C...
# 20                               [['Coil'], ['Coil']]
# 21  [['CXC_2', 'MSL2_CXC', 'consensus disorder pre...
# 22  [['consensus disorder prediction'], ['consensu...
# 23  [['PROPROTEIN CONVERTASE SUBTILISIN/KEXIN-RELA...
# 24  [['ODORANT RECEPTOR', '7tm Odorant receptor', ...
# 25  [['consensus disorder prediction'], ['consensu...
# 26  [['consensus disorder prediction'], ['consensu...
# 27  [['BTB domain profile.', 'KELCH PROTEIN', 'Pot...
# 28  [['consensus disorder prediction'], ['consensu...
# 29  [['ZINC FINGER PROTEIN 142', 'Zinc finger C2H2...
# 30  [['ODORANT BINDING PROTEIN-RELATED', 'PBP/GOBP...
# 31  [['consensus disorder prediction'], ['consensu...
# 32  [['consensus disorder prediction', 'PROTEIN IW...
# 33  [['consensus disorder prediction'], ['consensu...
# 34  [['consensus disorder prediction', 'HMG-I and ...
# 35  [['consensus disorder prediction'], ['consensu...
# 36  [['consensus disorder prediction', 'Zinc finge...
# 37  [['consensus disorder prediction', 'Coil'], ['...
# 38  [['Ig', 'Immunoglobulin domain', 'Ig-like doma...
# 39  [['consensus disorder prediction'], ['consensu...
# 40  [['consensus disorder prediction'], ['consensu...

# %%
OrthoGroup_GeneName_PresentWS = getMissingOrthogroup(OrthoGroup_GeneName_DM, OrthoGroup_GeneName_IntWS)
OrthoGroup_GeneName_WS = pd.merge(OrthoGroup_GeneName_DM, OrthoGroup_GeneName_PresentWS, on= 'Orthogroup')
OrthoGroup_GeneName_WS # this is the final df for which we couldnt find any function
# Out:
#     Orthogroup                                      Aedes_aegypti  \
# 0    OG0000010                                                NaN
# 1    OG0000029                                                NaN
# 2    OG0000042                                                NaN
# 3    OG0000345                                                NaN
# 4    OG0000761  AAEL006480-PA, AAEL006483-PB, AAEL006494-PB, A...
# ..         ...                                                ...
# 208  OG0011056                                                NaN
# 209  OG0011062                                                NaN
# 210  OG0011070                                                NaN
# 211  OG0011098                                                NaN
# 212  OG0011100                                                NaN
#
#                                      Anopheles_gambiae  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    AGAP007263-PA, AGAP007269-PA, AGAP007270-PA, A...
# 4          AGAP001174-PA, AGAP002643-PA, AGAP013066-PA
# ..                                                 ...
# 208                                                NaN
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
#
#                           Culex_quinquefasciatus  \
# 0    CPIJ014066-PA, CPIJ017401-PA, CPIJ017423-PA
# 1                                  CPIJ003782-PA
# 2                                  CPIJ007606-PA
# 3                                            NaN
# 4    CPIJ011560-PA, CPIJ011561-PA, CPIJ011562-PA
# ..                                           ...
# 208                                          NaN
# 209                                          NaN
# 210                                          NaN
# 211                                          NaN
# 212                                          NaN
#
#                    Drosophila_melanogaster  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4    FBpp0079366, FBpp0079367, FBpp0301576
# ..                                     ...
# 208               FBpp0086675, FBpp0086687
# 209               FBpp0292142, FBpp0307922
# 210               FBpp0111360, FBpp0290234
# 211                                    NaN
# 212                                    NaN
#
#                                       Wyeomyia_smithii
# 0    maker-tig00001022|arrow-exonerate_est2genome-g...
# 1    maker-tig00000321|arrow-exonerate_est2genome-g...
# 2    maker-tig00000213|arrow-exonerate_est2genome-g...
# 3                                                  NaN
# 4    maker-tig00031112|arrow-exonerate_est2genome-g...
# ..                                                 ...
# 208                                                NaN
# 209                                                NaN
# 210                                                NaN
# 211  maker-tig00010380|arrow-exonerate_est2genome-g...
# 212  maker-tig00013960|arrow-exonerate_est2genome-g...
#
# [213 rows x 6 columns]

# %% [markdown]
# ### Merging all the intermediate dataframes of the different species to get a final dataframe that contains all the Orthogroup along with respective functions

# %%
finalDF = OrthoGroup_GeneName_Int.append(OrthoGroup_GeneName_IntAG)
finalDF = finalDF.append(OrthoGroup_GeneName_IntCQ)
finalDF = finalDF.append(OrthoGroup_GeneName_IntDM)
finalDF = finalDF.append(OrthoGroup_GeneName_IntWS)
finalDF = finalDF.reset_index()
finalDF_7Cols = finalDF.drop("index", 1)
finalDF_7Cols = finalDF_7Cols[["Orthogroup","Function"]]
finalDF_7Cols
# Out:
#      Orthogroup                                           Function
# 0     OG0000001  [['DNA/RNA polymerases', '-', 'Reverse transcr...
# 1     OG0000005  [['FReD', 'Fibrinogen C-terminal domain-like',...
# 2     OG0000007  [['Histone', 'h2b3', 'Core histone H2A/H2B/H3/...
# 3     OG0000008  [['H15', 'HISTONE H1', '""winged helix"" repre...
# 4     OG0000009  [['Insect cuticle protein', 'Insect cuticle pr...
# ...         ...                                                ...
# 7991  OG0011105  [['consensus disorder prediction', 'Zinc finge...
# 7992  OG0011106  [['consensus disorder prediction', 'Coil'], ['...
# 7993  OG0011107  [['Ig', 'Immunoglobulin domain', 'Ig-like doma...
# 7994  OG0011108  [['consensus disorder prediction'], ['consensu...
# 7995  OG0011109  [['consensus disorder prediction'], ['consensu...
#
# [7996 rows x 2 columns]

# %%
Uniport_Function = UniportOutput[["Orthogroup","Function [CC]"]]
Uniport_Function = Uniport_Function.rename(columns={"Function [CC]":"Function"})
Uniport_Function
# Out:
#      Orthogroup                                           Function
# 0     OG0000002  ['FUNCTION: Core component of nucleosome. Nucl...
# 1     OG0000003  ['FUNCTION: Core component of nucleosome. Nucl...
# 2     OG0000004  ['FUNCTION: Variant histone H3 which replaces ...
# 3     OG0000006  ['FUNCTION: Cell adhesion molecule. {ECO:00002...
# 4     OG0000174  ['FUNCTION: Cell adhesion molecule. {ECO:00002...
# ...         ...                                                ...
# 2896  OG0008738  ['FUNCTION: Probably acts as a transcriptional...
# 2897  OG0009861  ['FUNCTION: Binds as a ligand to a family of f...
# 2898  OG0010523  ['FUNCTION: The Msl proteins are essential for...
# 2899  OG0010980  ['FUNCTION: Regulatory subunit of the dolichol...
# 2900  OG0011008  ['FUNCTION: Permease that is involved in the t...
#
# [2901 rows x 2 columns]

# %%
Final_OrthogroupFunctions = Uniport_Function.append(finalDF_7Cols)
Final_OrthogroupFunctions
# Out:
#      Orthogroup                                           Function
# 0     OG0000002  ['FUNCTION: Core component of nucleosome. Nucl...
# 1     OG0000003  ['FUNCTION: Core component of nucleosome. Nucl...
# 2     OG0000004  ['FUNCTION: Variant histone H3 which replaces ...
# 3     OG0000006  ['FUNCTION: Cell adhesion molecule. {ECO:00002...
# 4     OG0000174  ['FUNCTION: Cell adhesion molecule. {ECO:00002...
# ...         ...                                                ...
# 7991  OG0011105  [['consensus disorder prediction', 'Zinc finge...
# 7992  OG0011106  [['consensus disorder prediction', 'Coil'], ['...
# 7993  OG0011107  [['Ig', 'Immunoglobulin domain', 'Ig-like doma...
# 7994  OG0011108  [['consensus disorder prediction'], ['consensu...
# 7995  OG0011109  [['consensus disorder prediction'], ['consensu...
#
# [10897 rows x 2 columns]

# %%
Final_OrthogroupFunctions.to_excel("Final_OrthogroupFunctions.xlsx")
